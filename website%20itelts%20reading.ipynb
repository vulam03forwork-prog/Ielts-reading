# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice Website - CELL 1 (FIXED LAYOUT)
Index.html với Footer màu đen, gạch tím, layout cân bằng
"""

import os

# Tạo thư mục project
os.chdir('/content')
os.makedirs('ielts_reading_pro', exist_ok=True)
os.chdir('ielts_reading_pro')

index_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IELTS Reading Practice - Luyện thi IELTS Reading Online</title>

    <style>
        /* ==================== RESET CSS ==================== */
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        /* ==================== BODY ==================== */
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            min-height: 100vh;
        }

        /* ==================== HEADER ==================== */
        header {
            background: rgba(255, 255, 255, 0.98);
            padding: 1rem 2rem;
            box-shadow: 0 4px 20px rgba(0,0,0,0.1);
            backdrop-filter: blur(10px);
        }

        nav {
            display: flex;
            justify-content: space-between;
            align-items: center;
            max-width: 1200px;
            margin: 0 auto;
        }

        .logo {
            font-size: 1.8rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .nav-links {
            display: flex;
            gap: 2rem;
            align-items: center;
        }

        .nav-links a {
            text-decoration: none;
            color: #333;
            font-weight: 600;
            transition: all 0.3s;
            position: relative;
        }

        .nav-links a:hover {
            color: #667eea;
            transform: translateY(-2px);
        }

        .nav-links a::after {
            content: '';
            position: absolute;
            width: 0;
            height: 2px;
            bottom: -5px;
            left: 50%;
            background: #667eea;
            transition: all 0.3s;
            transform: translateX(-50%);
        }

        .nav-links a:hover::after {
            width: 100%;
        }

        /* ==================== HERO SECTION ==================== */
        .hero {
            display: flex;
            flex-direction: column;
            justify-content: center;
            align-items: center;
            text-align: center;
            padding: 5rem 2rem 4rem;
            color: white;
            min-height: 60vh;
        }

        .hero h1 {
            font-size: 3.5rem;
            margin-bottom: 1rem;
            animation: fadeInUp 0.8s ease-out;
            text-shadow: 2px 2px 4px rgba(0,0,0,0.2);
        }

        .hero p {
            font-size: 1.3rem;
            margin-bottom: 2.5rem;
            max-width: 700px;
            line-height: 1.6;
            animation: fadeInUp 1s ease-out;
            text-shadow: 1px 1px 2px rgba(0,0,0,0.2);
        }

        @keyframes fadeInUp {
            from {
                opacity: 0;
                transform: translateY(30px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        .btn-group {
            display: flex;
            gap: 1rem;
            animation: fadeInUp 1.2s ease-out;
        }

        .btn {
            padding: 1.2rem 2.5rem;
            font-size: 1.1rem;
            font-weight: 600;
            border: none;
            border-radius: 50px;
            cursor: pointer;
            text-decoration: none;
            transition: all 0.3s ease;
            display: inline-flex;
            align-items: center;
            gap: 0.5rem;
        }

        .btn-primary {
            background: white;
            color: #667eea;
            box-shadow: 0 4px 15px rgba(0,0,0,0.2);
        }

        .btn-primary:hover {
            transform: translateY(-3px);
            box-shadow: 0 8px 25px rgba(0,0,0,0.3);
        }

        .btn-secondary {
            background: transparent;
            color: white;
            border: 2px solid white;
        }

        .btn-secondary:hover {
            background: white;
            color: #667eea;
            transform: translateY(-3px);
            box-shadow: 0 8px 25px rgba(0,0,0,0.3);
        }

        /* ==================== STATS ==================== */
        .stats {
            background: rgba(102, 126, 234, 0.95);
            padding: 3rem 2rem;
            color: white;
        }

        .stats-container {
            max-width: 1200px;
            margin: 0 auto;
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
            gap: 2rem;
            text-align: center;
        }

        .stat-item h3 {
            font-size: 3rem;
            margin-bottom: 0.5rem;
        }

        .stat-item p {
            font-size: 1.1rem;
            opacity: 0.9;
        }

        /* ==================== FEATURES ==================== */
        .features {
            background: white;
            padding: 4rem 2rem;
        }

        .features h2 {
            text-align: center;
            font-size: 2.5rem;
            color: #333;
            margin-bottom: 3rem;
        }

        .features-container {
            max-width: 1200px;
            margin: 0 auto;
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(280px, 1fr));
            gap: 2rem;
        }

        .feature-card {
            text-align: center;
            padding: 2.5rem;
            border-radius: 15px;
            background: #f8f9fa;
            transition: all 0.3s ease;
            border: 2px solid transparent;
        }

        .feature-card:hover {
            transform: translateY(-10px);
            box-shadow: 0 10px 30px rgba(102, 126, 234, 0.3);
            border-color: #667eea;
        }

        .feature-icon {
            font-size: 3rem;
            margin-bottom: 1rem;
        }

        .feature-card h3 {
            color: #667eea;
            margin: 1rem 0;
            font-size: 1.3rem;
        }

        .feature-card p {
            color: #666;
            line-height: 1.6;
        }

        /* ==================== FOOTER MÀU ĐEN VỚI GẠCH TÍM ==================== */
        footer {
            background: #000000;
            color: #d1d5db;
            padding: 0;
            margin-top: 3rem;
            border-top: 4px solid #8b5cf6;
        }

        .footer-content {
            max-width: 1200px;
            margin: 0 auto;
            padding: 3rem 2rem 2rem;
            display: grid;
            grid-template-columns: 2fr 1.2fr 1.2fr;
            gap: 3rem;
        }

        .footer-section h3 {
            color: #8b5cf6;
            margin-bottom: 1.2rem;
            font-size: 1.2rem;
            display: flex;
            align-items: center;
            gap: 0.5rem;
            font-weight: 700;
        }

        .footer-section p {
            color: #d1d5db;
            line-height: 1.8;
            margin-bottom: 0.6rem;
            font-size: 0.95rem;
        }

        .footer-section p strong {
            color: #8b5cf6;
            font-weight: 600;
        }

        .footer-section a {
            color: #60a5fa;
            text-decoration: none;
            display: block;
            margin-bottom: 0.6rem;
            transition: all 0.3s;
            font-size: 0.95rem;
        }

        .footer-section a:hover {
            color: #93c5fd;
            padding-left: 8px;
        }

        .social-links {
            display: flex;
            gap: 1rem;
            margin-top: 1.2rem;
        }

        .social-links a {
            width: 42px;
            height: 42px;
            border-radius: 50%;
            background: #8b5cf6;
            color: white;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 1.2rem;
            transition: all 0.3s;
            padding-left: 0;
        }

        .social-links a:hover {
            background: #a78bfa;
            transform: translateY(-4px);
            box-shadow: 0 4px 12px rgba(139, 92, 246, 0.5);
            padding-left: 0;
        }

        .footer-bottom {
            text-align: center;
            padding: 1.5rem 2rem;
            border-top: 1px solid #1f2937;
            color: #9ca3af;
            background: #0a0a0a;
        }

        .footer-bottom p {
            margin: 0.3rem 0;
            font-size: 0.9rem;
            color: #9ca3af;
        }

        .footer-bottom .heart {
            color: #ef4444;
            animation: heartbeat 1.5s ease-in-out infinite;
        }

        @keyframes heartbeat {
            0%, 100% { transform: scale(1); }
            25% { transform: scale(1.15); }
            50% { transform: scale(1); }
            75% { transform: scale(1.1); }
        }

        /* ==================== RESPONSIVE ==================== */
        @media (max-width: 1024px) {
            .footer-content {
                grid-template-columns: 1fr 1fr;
                gap: 2.5rem;
            }

            .footer-section:first-child {
                grid-column: 1 / -1;
            }
        }

        @media (max-width: 768px) {
            .hero h1 {
                font-size: 2.5rem;
            }

            .hero p {
                font-size: 1.1rem;
            }

            .btn-group {
                flex-direction: column;
                width: 100%;
            }

            .btn {
                width: 100%;
                justify-content: center;
            }

            .nav-links {
                gap: 1rem;
            }

            .footer-content {
                grid-template-columns: 1fr;
                gap: 2rem;
                padding: 2.5rem 1.5rem 1.5rem;
            }

            .footer-section:first-child {
                grid-column: 1;
            }

            .social-links {
                justify-content: flex-start;
            }
        }
    </style>
</head>
<body>
    <!-- ==================== HEADER ==================== -->
    <header>
        <nav>
            <div class="logo">
                <span>📚</span>
                <span>IELTS Reading Pro</span>
            </div>
            <div class="nav-links">
                <a href="index.html">Trang chủ</a>
                <a href="login.html">Đăng nhập</a>
                <a href="register.html">Đăng ký</a>
            </div>
        </nav>
    </header>

    <!-- ==================== HERO ==================== -->
    <section class="hero">
        <h1>🎯 Luyện IELTS Reading Online</h1>
        <p>Nâng cao kỹ năng đọc hiểu với 5 bài test thực chiến đa dạng chủ đề.
           Timer linh hoạt, chấm điểm tự động và theo dõi tiến độ chi tiết!</p>
        <div class="btn-group">
            <a href="register.html" class="btn btn-primary">
                <span>🚀</span>
                <span>Bắt đầu miễn phí</span>
            </a>
            <a href="login.html" class="btn btn-secondary">
                <span>👤</span>
                <span>Đăng nhập</span>
            </a>
        </div>
    </section>

    <!-- ==================== STATS ==================== -->
    <section class="stats">
        <div class="stats-container">
            <div class="stat-item">
                <h3>5</h3>
                <p>Bài test hoàn chỉnh</p>
            </div>
            <div class="stat-item">
                <h3>8</h3>
                <p>Câu hỏi mỗi bài</p>
            </div>
            <div class="stat-item">
                <h3>100%</h3>
                <p>Miễn phí</p>
            </div>
            <div class="stat-item">
                <h3>24/7</h3>
                <p>Luyện tập mọi lúc</p>
            </div>
        </div>
    </section>

    <!-- ==================== FEATURES ==================== -->
    <section class="features">
        <h2>✨ Tính năng nổi bật</h2>
        <div class="features-container">
            <div class="feature-card">
                <div class="feature-icon">⏱️</div>
                <h3>Timer Linh Hoạt</h3>
                <p>Chọn 60 phút như thi thật hoặc không giới hạn thời gian để học tập</p>
            </div>

            <div class="feature-card">
                <div class="feature-icon">📊</div>
                <h3>Chấm Điểm Tự Động</h3>
                <p>Kết quả chi tiết ngay sau khi làm xong, xem đáp án đúng/sai từng câu</p>
            </div>

            <div class="feature-card">
                <div class="feature-icon">📈</div>
                <h3>Theo Dõi Tiến Độ</h3>
                <p>Thống kê điểm số, độ chính xác và lịch sử làm bài đầy đủ</p>
            </div>

            <div class="feature-card">
                <div class="feature-icon">📚</div>
                <h3>5 Chủ Đề Đa Dạng</h3>
                <p>Từ Khoa học, Công nghệ đến Văn hóa, Sức khỏe và Môi trường</p>
            </div>

            <div class="feature-card">
                <div class="feature-icon">💾</div>
                <h3>Lưu Tiến Trình</h3>
                <p>Dữ liệu được lưu tự động, làm bài mọi lúc mọi nơi</p>
            </div>

            <div class="feature-card">
                <div class="feature-icon">🎯</div>
                <h3>Giao Diện Thân Thiện</h3>
                <p>Thiết kế đơn giản, dễ sử dụng, tập trung vào việc học</p>
            </div>
        </div>
    </section>

    <!-- ==================== FOOTER MÀU ĐEN VỚI GẠCH TÍM ==================== -->
    <footer>
        <div class="footer-content">
            <!-- Phần giới thiệu project -->
            <div class="footer-section">
                <h3>📚 IELTS Reading Pro</h3>
                <p>Nền tảng luyện thi IELTS Reading online hoàn toàn miễn phí với 5 bài test thực chiến.</p>
                <p style="margin-top: 1.2rem;">
                    <strong>Dự án Tin học 12</strong><br>
                    Trung Học Phổ Thông Võ Trường Toản<br>
                    Năm học 2025-2026
                </p>
            </div>

            <!-- Phần thông tin nhóm -->
            <div class="footer-section">
                <h3>👥 Ký tên</h3>
                <p><strong>tên:</strong> Hoàng Thị Ngọc Huyền</p>
                <p><strong>tên:</strong> Huỳnh Ngọc Kim Ngân</p>
                <p><strong>tên:</strong> Quản Thị Thuỳ Linh</p>
                <p><strong>tên:</strong> Hoàng Quốc Huy</p>
            </div>

            <!-- Phần liên hệ -->
            <div class="footer-section">
                <h3>📞 Liên hệ</h3>
                <a href="tel:+84843927xxx">📱 0843927xxx</a>
                <a href="#" style="pointer-events: none; opacity: 0.7;">📍 TP Hồ Chí Minh, Việt Nam</a>

                <!-- Social media links -->
                <div class="social-links">
                    <a href="#" title="Facebook">📘</a>
                    <a href="#" title="YouTube">▶️</a>
                    <a href="#" title="Instagram">📷</a>
                    <a href="#" title="Twitter">🐦</a>
                </div>
            </div>
        </div>

        <!-- Copyright -->
        <div class="footer-bottom">
            <p><strong>© 2025 IELTS Reading Pro</strong> - Dự án Tin học 12 - Truờng THPT Võ Trường Toản</p>
            <p>Made with <span class="heart">❤️</span> for IELTS learners</p>
        </div>
    </footer>
</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice Website - CELL 2
Tạo file register.html (Trang đăng ký)
"""

# ==================== FILE REGISTER.HTML ====================
register_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Đăng ký - IELTS Reading Pro</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            min-height: 100vh;
            display: flex;
            justify-content: center;
            align-items: center;
            padding: 2rem;
        }

        .container {
            background: white;
            padding: 3rem;
            border-radius: 25px;
            box-shadow: 0 25px 70px rgba(0,0,0,0.4);
            max-width: 480px;
            width: 100%;
            animation: slideUp 0.5s ease-out;
        }

        @keyframes slideUp {
            from {
                opacity: 0;
                transform: translateY(30px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        .logo {
            text-align: center;
            font-size: 2.5rem;
            margin-bottom: 0.5rem;
        }

        .brand-name {
            text-align: center;
            font-size: 1.8rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
            margin-bottom: 0.5rem;
        }

        h2 {
            text-align: center;
            color: #333;
            margin-bottom: 2rem;
            font-size: 1.5rem;
        }

        .form-group {
            margin-bottom: 1.5rem;
        }

        label {
            display: block;
            margin-bottom: 0.5rem;
            color: #555;
            font-weight: 600;
            font-size: 0.95rem;
        }

        .input-container {
            position: relative;
        }

        .input-icon {
            position: absolute;
            left: 1rem;
            top: 50%;
            transform: translateY(-50%);
            color: #999;
            font-size: 1.2rem;
        }

        input {
            width: 100%;
            padding: 1rem 1rem 1rem 3rem;
            border: 2px solid #e0e0e0;
            border-radius: 12px;
            font-size: 1rem;
            transition: all 0.3s;
            background: #f8f9fa;
        }

        input:focus {
            outline: none;
            border-color: #667eea;
            background: white;
            box-shadow: 0 0 0 4px rgba(102, 126, 234, 0.1);
        }

        input.error {
            border-color: #f44336;
        }

        input.success {
            border-color: #4caf50;
        }

        .error-message {
            color: #f44336;
            font-size: 0.85rem;
            margin-top: 0.5rem;
            display: none;
        }

        .error-message.show {
            display: block;
        }

        .password-toggle {
            position: absolute;
            right: 1rem;
            top: 50%;
            transform: translateY(-50%);
            cursor: pointer;
            color: #999;
            font-size: 1.2rem;
            user-select: none;
        }

        .password-toggle:hover {
            color: #667eea;
        }

        .password-strength {
            margin-top: 0.5rem;
            font-size: 0.85rem;
        }

        .strength-bar {
            height: 4px;
            background: #e0e0e0;
            border-radius: 2px;
            margin-top: 0.3rem;
            overflow: hidden;
        }

        .strength-fill {
            height: 100%;
            width: 0%;
            transition: all 0.3s;
        }

        .strength-weak { background: #f44336; width: 33%; }
        .strength-medium { background: #ff9800; width: 66%; }
        .strength-strong { background: #4caf50; width: 100%; }

        .btn {
            width: 100%;
            padding: 1.2rem;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border: none;
            border-radius: 12px;
            font-size: 1.1rem;
            font-weight: 600;
            cursor: pointer;
            transition: all 0.3s;
            margin-top: 1rem;
        }

        .btn:hover {
            transform: translateY(-2px);
            box-shadow: 0 8px 20px rgba(102, 126, 234, 0.4);
        }

        .btn:active {
            transform: translateY(0);
        }

        .btn:disabled {
            opacity: 0.6;
            cursor: not-allowed;
        }

        .link {
            text-align: center;
            margin-top: 1.5rem;
            color: #666;
        }

        .link a {
            color: #667eea;
            text-decoration: none;
            font-weight: 600;
        }

        .link a:hover {
            text-decoration: underline;
        }

        .message {
            padding: 1rem;
            margin-bottom: 1rem;
            border-radius: 12px;
            display: none;
            animation: slideDown 0.3s ease-out;
        }

        @keyframes slideDown {
            from {
                opacity: 0;
                transform: translateY(-10px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        .message.success {
            background: #d4edda;
            color: #155724;
            border: 2px solid #c3e6cb;
        }

        .message.error {
            background: #f8d7da;
            color: #721c24;
            border: 2px solid #f5c6cb;
        }

        .message.show {
            display: block;
        }

        .divider {
            text-align: center;
            margin: 1.5rem 0;
            color: #999;
            position: relative;
        }

        .divider::before,
        .divider::after {
            content: '';
            position: absolute;
            top: 50%;
            width: 40%;
            height: 1px;
            background: #e0e0e0;
        }

        .divider::before { left: 0; }
        .divider::after { right: 0; }

        @media (max-width: 480px) {
            .container {
                padding: 2rem 1.5rem;
            }
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="logo">📚</div>
        <div class="brand-name">IELTS Reading Pro</div>
        <h2>Tạo tài khoản mới</h2>

        <div id="message" class="message"></div>

        <form id="registerForm">
            <div class="form-group">
                <label for="fullname">Họ và tên</label>
                <div class="input-container">
                    <span class="input-icon">👤</span>
                    <input
                        type="text"
                        id="fullname"
                        placeholder="Nguyễn Văn A"
                        required
                    >
                </div>
                <div class="error-message" id="fullnameError"></div>
            </div>

            <div class="form-group">
                <label for="email">Email</label>
                <div class="input-container">
                    <span class="input-icon">✉️</span>
                    <input
                        type="email"
                        id="email"
                        placeholder="example@email.com"
                        required
                    >
                </div>
                <div class="error-message" id="emailError"></div>
            </div>

            <div class="form-group">
                <label for="password">Mật khẩu</label>
                <div class="input-container">
                    <span class="input-icon">🔒</span>
                    <input
                        type="password"
                        id="password"
                        placeholder="Tối thiểu 6 ký tự"
                        required
                    >
                    <span class="password-toggle" onclick="togglePassword('password')">👁️</span>
                </div>
                <div class="password-strength">
                    <div class="strength-bar">
                        <div class="strength-fill" id="strengthFill"></div>
                    </div>
                    <span id="strengthText"></span>
                </div>
                <div class="error-message" id="passwordError"></div>
            </div>

            <div class="form-group">
                <label for="confirmPassword">Xác nhận mật khẩu</label>
                <div class="input-container">
                    <span class="input-icon">🔒</span>
                    <input
                        type="password"
                        id="confirmPassword"
                        placeholder="Nhập lại mật khẩu"
                        required
                    >
                    <span class="password-toggle" onclick="togglePassword('confirmPassword')">👁️</span>
                </div>
                <div class="error-message" id="confirmPasswordError"></div>
            </div>

            <button type="submit" class="btn" id="submitBtn">
                🚀 Đăng ký ngay
            </button>
        </form>

        <div class="divider">hoặc</div>

        <div class="link">
            Đã có tài khoản? <a href="login.html">Đăng nhập ngay</a>
        </div>

        <div class="link">
            <a href="index.html">← Về trang chủ</a>
        </div>
    </div>

    <script>
        const form = document.getElementById('registerForm');
        const inputs = {
            fullname: document.getElementById('fullname'),
            email: document.getElementById('email'),
            password: document.getElementById('password'),
            confirmPassword: document.getElementById('confirmPassword')
        };

        // Password strength checker
        inputs.password.addEventListener('input', function() {
            const password = this.value;
            const strengthFill = document.getElementById('strengthFill');
            const strengthText = document.getElementById('strengthText');

            if (password.length === 0) {
                strengthFill.className = 'strength-fill';
                strengthText.textContent = '';
                return;
            }

            let strength = 0;
            if (password.length >= 6) strength++;
            if (password.length >= 10) strength++;
            if (/[a-z]/.test(password) && /[A-Z]/.test(password)) strength++;
            if (/\d/.test(password)) strength++;
            if (/[^a-zA-Z\d]/.test(password)) strength++;

            if (strength <= 2) {
                strengthFill.className = 'strength-fill strength-weak';
                strengthText.textContent = '🔴 Yếu';
                strengthText.style.color = '#f44336';
            } else if (strength <= 4) {
                strengthFill.className = 'strength-fill strength-medium';
                strengthText.textContent = '🟡 Trung bình';
                strengthText.style.color = '#ff9800';
            } else {
                strengthFill.className = 'strength-fill strength-strong';
                strengthText.textContent = '🟢 Mạnh';
                strengthText.style.color = '#4caf50';
            }
        });

        // Toggle password visibility
        function togglePassword(fieldId) {
            const field = document.getElementById(fieldId);
            field.type = field.type === 'password' ? 'text' : 'password';
        }

        // Show message
        function showMessage(text, type) {
            const msg = document.getElementById('message');
            msg.textContent = text;
            msg.className = 'message ' + type + ' show';
            setTimeout(() => {
                msg.classList.remove('show');
            }, 4000);
        }

        // Validate field
        function validateField(field, errorId, validator) {
            const errorEl = document.getElementById(errorId);
            const result = validator(field.value);

            if (result.valid) {
                field.classList.remove('error');
                field.classList.add('success');
                errorEl.classList.remove('show');
                return true;
            } else {
                field.classList.add('error');
                field.classList.remove('success');
                errorEl.textContent = result.message;
                errorEl.classList.add('show');
                return false;
            }
        }

        // Validators
        const validators = {
            fullname: (value) => {
                if (!value.trim()) return { valid: false, message: 'Vui lòng nhập họ tên' };
                if (value.trim().length < 3) return { valid: false, message: 'Họ tên quá ngắn' };
                return { valid: true };
            },
            email: (value) => {
                if (!value.trim()) return { valid: false, message: 'Vui lòng nhập email' };
                const emailRegex = /^[^\s@]+@[^\s@]+\.[^\s@]+$/;
                if (!emailRegex.test(value)) return { valid: false, message: 'Email không hợp lệ' };
                return { valid: true };
            },
            password: (value) => {
                if (!value) return { valid: false, message: 'Vui lòng nhập mật khẩu' };
                if (value.length < 6) return { valid: false, message: 'Mật khẩu phải có ít nhất 6 ký tự' };
                return { valid: true };
            },
            confirmPassword: (value) => {
                if (!value) return { valid: false, message: 'Vui lòng xác nhận mật khẩu' };
                if (value !== inputs.password.value) return { valid: false, message: 'Mật khẩu không khớp' };
                return { valid: true };
            }
        };

        // Real-time validation
        Object.keys(inputs).forEach(key => {
            inputs[key].addEventListener('blur', () => {
                validateField(inputs[key], key + 'Error', validators[key]);
            });
        });

        // Form submit
        form.addEventListener('submit', function(e) {
            e.preventDefault();

            // Validate all fields
            let isValid = true;
            Object.keys(inputs).forEach(key => {
                if (!validateField(inputs[key], key + 'Error', validators[key])) {
                    isValid = false;
                }
            });

            if (!isValid) {
                showMessage('Vui lòng kiểm tra lại thông tin!', 'error');
                return;
            }

            // Check if email exists
            let users = JSON.parse(localStorage.getItem('users') || '[]');
            if (users.find(u => u.email === inputs.email.value.trim())) {
                showMessage('Email này đã được đăng ký!', 'error');
                inputs.email.classList.add('error');
                return;
            }

            // Create new user
            const newUser = {
                id: Date.now(),
                fullname: inputs.fullname.value.trim(),
                email: inputs.email.value.trim(),
                password: inputs.password.value,
                createdAt: new Date().toISOString(),
                testHistory: []
            };

            users.push(newUser);
            localStorage.setItem('users', JSON.stringify(users));

            showMessage('✅ Đăng ký thành công! Đang chuyển đến trang đăng nhập...', 'success');

            setTimeout(() => {
                window.location.href = 'login.html';
            }, 2000);
        });

        // Enter to submit
        Object.values(inputs).forEach(input => {
            input.addEventListener('keypress', (e) => {
                if (e.key === 'Enter') {
                    e.preventDefault();
                    form.dispatchEvent(new Event('submit'));
                }
            });
        });
    </script>
</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice Website - CELL 3 (FIXED)
Tạo file login.html - SỬA LỖI ĐĂNG NHẬP
"""

# ==================== FILE LOGIN.HTML (FIXED) ====================
login_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Đăng nhập - IELTS Reading Pro</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            min-height: 100vh;
            display: flex;
            justify-content: center;
            align-items: center;
            padding: 2rem;
        }

        .container {
            background: white;
            padding: 3rem;
            border-radius: 25px;
            box-shadow: 0 25px 70px rgba(0,0,0,0.4);
            max-width: 450px;
            width: 100%;
            animation: slideUp 0.5s ease-out;
        }

        @keyframes slideUp {
            from {
                opacity: 0;
                transform: translateY(30px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        .logo {
            text-align: center;
            font-size: 3rem;
            margin-bottom: 0.5rem;
        }

        .brand-name {
            text-align: center;
            font-size: 1.8rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
            margin-bottom: 0.5rem;
        }

        h2 {
            text-align: center;
            color: #333;
            margin-bottom: 2rem;
            font-size: 1.5rem;
        }

        .form-group {
            margin-bottom: 1.5rem;
        }

        label {
            display: block;
            margin-bottom: 0.5rem;
            color: #555;
            font-weight: 600;
            font-size: 0.95rem;
        }

        .input-container {
            position: relative;
        }

        .input-icon {
            position: absolute;
            left: 1rem;
            top: 50%;
            transform: translateY(-50%);
            color: #999;
            font-size: 1.2rem;
        }

        input {
            width: 100%;
            padding: 1rem 1rem 1rem 3rem;
            border: 2px solid #e0e0e0;
            border-radius: 12px;
            font-size: 1rem;
            transition: all 0.3s;
            background: #f8f9fa;
        }

        input:focus {
            outline: none;
            border-color: #667eea;
            background: white;
            box-shadow: 0 0 0 4px rgba(102, 126, 234, 0.1);
        }

        input.error {
            border-color: #f44336;
            animation: shake 0.5s;
        }

        @keyframes shake {
            0%, 100% { transform: translateX(0); }
            25% { transform: translateX(-10px); }
            75% { transform: translateX(10px); }
        }

        .password-toggle {
            position: absolute;
            right: 1rem;
            top: 50%;
            transform: translateY(-50%);
            cursor: pointer;
            color: #999;
            font-size: 1.2rem;
            user-select: none;
        }

        .password-toggle:hover {
            color: #667eea;
        }

        .remember-forgot {
            display: flex;
            justify-content: space-between;
            align-items: center;
            margin-bottom: 1.5rem;
            font-size: 0.9rem;
        }

        .remember-me {
            display: flex;
            align-items: center;
            gap: 0.5rem;
            cursor: pointer;
        }

        .remember-me input[type="checkbox"] {
            width: auto;
            cursor: pointer;
        }

        .forgot-password {
            color: #667eea;
            text-decoration: none;
            font-weight: 600;
        }

        .forgot-password:hover {
            text-decoration: underline;
        }

        .btn {
            width: 100%;
            padding: 1.2rem;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border: none;
            border-radius: 12px;
            font-size: 1.1rem;
            font-weight: 600;
            cursor: pointer;
            transition: all 0.3s;
            display: flex;
            align-items: center;
            justify-content: center;
            gap: 0.5rem;
        }

        .btn:hover {
            transform: translateY(-2px);
            box-shadow: 0 8px 20px rgba(102, 126, 234, 0.4);
        }

        .btn:active {
            transform: translateY(0);
        }

        .btn:disabled {
            opacity: 0.6;
            cursor: not-allowed;
        }

        .btn .spinner {
            width: 20px;
            height: 20px;
            border: 3px solid rgba(255,255,255,0.3);
            border-top-color: white;
            border-radius: 50%;
            animation: spin 0.8s linear infinite;
            display: none;
        }

        @keyframes spin {
            to { transform: rotate(360deg); }
        }

        .btn.loading .spinner {
            display: block;
        }

        .btn.loading .btn-text {
            display: none;
        }

        .link {
            text-align: center;
            margin-top: 1.5rem;
            color: #666;
        }

        .link a {
            color: #667eea;
            text-decoration: none;
            font-weight: 600;
        }

        .link a:hover {
            text-decoration: underline;
        }

        .message {
            padding: 1rem;
            margin-bottom: 1rem;
            border-radius: 12px;
            display: none;
            animation: slideDown 0.3s ease-out;
        }

        @keyframes slideDown {
            from {
                opacity: 0;
                transform: translateY(-10px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        .message.success {
            background: #d4edda;
            color: #155724;
            border: 2px solid #c3e6cb;
        }

        .message.error {
            background: #f8d7da;
            color: #721c24;
            border: 2px solid #f5c6cb;
        }

        .message.show {
            display: block;
        }

        .divider {
            text-align: center;
            margin: 1.5rem 0;
            color: #999;
            position: relative;
        }

        .divider::before,
        .divider::after {
            content: '';
            position: absolute;
            top: 50%;
            width: 40%;
            height: 1px;
            background: #e0e0e0;
        }

        .divider::before { left: 0; }
        .divider::after { right: 0; }

        .demo-account {
            background: #fff3cd;
            border: 2px solid #ffc107;
            border-radius: 12px;
            padding: 1rem;
            margin-bottom: 1.5rem;
            font-size: 0.9rem;
        }

        .demo-account strong {
            color: #856404;
            display: block;
            margin-bottom: 0.5rem;
        }

        .demo-account code {
            background: white;
            padding: 0.2rem 0.5rem;
            border-radius: 4px;
            font-family: monospace;
        }

        @media (max-width: 480px) {
            .container {
                padding: 2rem 1.5rem;
            }

            .remember-forgot {
                flex-direction: column;
                gap: 0.5rem;
                align-items: flex-start;
            }
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="logo">📚</div>
        <div class="brand-name">IELTS Reading Pro</div>
        <h2>Đăng nhập vào tài khoản</h2>

        <div id="message" class="message"></div>

        <div class="demo-account">
            <strong>💡 Tài khoản demo để test:</strong>
            Email: <code>demo@test.com</code><br>
            Password: <code>123456</code>
        </div>

        <form id="loginForm">
            <div class="form-group">
                <label for="email">Email</label>
                <div class="input-container">
                    <span class="input-icon">✉️</span>
                    <input
                        type="email"
                        id="email"
                        placeholder="example@email.com"
                        required
                        autocomplete="email"
                    >
                </div>
            </div>

            <div class="form-group">
                <label for="password">Mật khẩu</label>
                <div class="input-container">
                    <span class="input-icon">🔒</span>
                    <input
                        type="password"
                        id="password"
                        placeholder="Nhập mật khẩu"
                        required
                        autocomplete="current-password"
                    >
                    <span class="password-toggle" onclick="togglePassword()">👁️</span>
                </div>
            </div>

            <div class="remember-forgot">
                <label class="remember-me">
                    <input type="checkbox" id="rememberMe">
                    <span>Ghi nhớ đăng nhập</span>
                </label>
                <a href="#" class="forgot-password" onclick="forgotPassword(event)">Quên mật khẩu?</a>
            </div>

            <button type="submit" class="btn" id="submitBtn">
                <span class="spinner"></span>
                <span class="btn-text">🚀 Đăng nhập</span>
            </button>
        </form>

        <div class="divider">hoặc</div>

        <div class="link">
            Chưa có tài khoản? <a href="register.html">Đăng ký ngay</a>
        </div>

        <div class="link">
            <a href="index.html">← Về trang chủ</a>
        </div>
    </div>

    <script>
        const form = document.getElementById('loginForm');
        const emailInput = document.getElementById('email');
        const passwordInput = document.getElementById('password');
        const rememberMeCheckbox = document.getElementById('rememberMe');
        const submitBtn = document.getElementById('submitBtn');

        // Toggle password visibility
        function togglePassword() {
            const field = document.getElementById('password');
            field.type = field.type === 'password' ? 'text' : 'password';
        }

        // Show message
        function showMessage(text, type) {
            const msg = document.getElementById('message');
            msg.textContent = text;
            msg.className = 'message ' + type + ' show';
            setTimeout(() => {
                msg.classList.remove('show');
            }, 4000);
        }

        // Forgot password
        function forgotPassword(e) {
            e.preventDefault();
            alert('Tính năng đặt lại mật khẩu đang được phát triển.\\nVui lòng liên hệ admin để được hỗ trợ.');
        }

        // Load remembered email
        window.addEventListener('load', () => {
            const rememberedEmail = localStorage.getItem('rememberedEmail');
            if (rememberedEmail) {
                emailInput.value = rememberedEmail;
                rememberMeCheckbox.checked = true;
            }
        });

        // Create demo account if not exists
        function ensureDemoAccount() {
            let users = JSON.parse(localStorage.getItem('users') || '[]');

            if (!users.find(u => u.email === 'demo@test.com')) {
                const demoUser = {
                    id: 999999,
                    fullname: 'Demo User',
                    email: 'demo@test.com',
                    password: '123456',
                    createdAt: new Date().toISOString(),
                    testHistory: []
                };
                users.push(demoUser);
                localStorage.setItem('users', JSON.stringify(users));
                console.log('✅ Demo account created');
            }
        }

        ensureDemoAccount();

        // Form submit - FIXED VERSION
        form.addEventListener('submit', function(e) {
            e.preventDefault();

            const email = emailInput.value.trim();
            const password = passwordInput.value;

            console.log('🔐 Attempting login for:', email);

            // Validation
            if (!email || !password) {
                showMessage('Vui lòng điền đầy đủ thông tin!', 'error');
                if (!email) emailInput.classList.add('error');
                if (!password) passwordInput.classList.add('error');
                return;
            }

            // Remove error states
            emailInput.classList.remove('error');
            passwordInput.classList.remove('error');

            // Show loading
            submitBtn.classList.add('loading');
            submitBtn.disabled = true;

            // Simulate network delay
            setTimeout(() => {
                try {
                    const users = JSON.parse(localStorage.getItem('users') || '[]');
                    console.log('📊 Total users in DB:', users.length);

                    const user = users.find(u => u.email === email && u.password === password);

                    if (!user) {
                        console.log('❌ Login failed: Invalid credentials');
                        showMessage('❌ Email hoặc mật khẩu không đúng!', 'error');
                        emailInput.classList.add('error');
                        passwordInput.classList.add('error');
                        submitBtn.classList.remove('loading');
                        submitBtn.disabled = false;
                        return;
                    }

                    console.log('✅ User found:', user.fullname);

                    // Save remember me
                    if (rememberMeCheckbox.checked) {
                        localStorage.setItem('rememberedEmail', email);
                        console.log('💾 Email remembered');
                    } else {
                        localStorage.removeItem('rememberedEmail');
                    }

                    // CRITICAL: Save current user with error handling
                    try {
                        localStorage.setItem('currentUser', JSON.stringify(user));
                        console.log('💾 Current user saved to localStorage');

                        // Verify it was saved correctly
                        const savedUser = localStorage.getItem('currentUser');
                        if (!savedUser) {
                            throw new Error('Failed to save user to localStorage');
                        }

                        const parsedUser = JSON.parse(savedUser);
                        console.log('✅ Verified saved user:', parsedUser.email);

                        showMessage('✅ Đăng nhập thành công!', 'success');

                        // Redirect after delay
                        setTimeout(() => {
                            console.log('🔄 Redirecting to dashboard...');
                            window.location.href = 'dashboard.html';
                        }, 1000);

                    } catch (storageError) {
                        console.error('❌ LocalStorage error:', storageError);
                        showMessage('❌ Lỗi lưu thông tin. Vui lòng thử lại!', 'error');
                        submitBtn.classList.remove('loading');
                        submitBtn.disabled = false;
                    }

                } catch (error) {
                    console.error('❌ Login error:', error);
                    showMessage('❌ Lỗi hệ thống. Vui lòng thử lại!', 'error');
                    submitBtn.classList.remove('loading');
                    submitBtn.disabled = false;
                }
            }, 800);
        });

        // Enter to submit
        [emailInput, passwordInput].forEach(input => {
            input.addEventListener('keypress', (e) => {
                if (e.key === 'Enter') {
                    e.preventDefault();
                    form.dispatchEvent(new Event('submit'));
                }
            });
        });

        // Remove error on input
        emailInput.addEventListener('input', () => {
            emailInput.classList.remove('error');
        });

        passwordInput.addEventListener('input', () => {
            passwordInput.classList.remove('error');
        });

        // Debug: Check localStorage on page load
        console.log('🔍 Current user on load:', localStorage.getItem('currentUser'));
    </script>

</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice Website - CELL 4 (FIXED LAYOUT)
Dashboard với Footer màu đen, gạch tím, layout cân bằng
"""

dashboard_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Dashboard - IELTS Reading Pro</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: #f5f7fa;
            min-height: 100vh;
        }

        header {
            background: white;
            padding: 1rem 2rem;
            box-shadow: 0 2px 15px rgba(0,0,0,0.1);
            position: sticky;
            top: 0;
            z-index: 100;
        }

        nav {
            display: flex;
            justify-content: space-between;
            align-items: center;
            max-width: 1400px;
            margin: 0 auto;
        }

        .logo {
            font-size: 1.5rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .user-info {
            display: flex;
            align-items: center;
            gap: 1.5rem;
        }

        .user-name {
            font-weight: 600;
            color: #333;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .btn-logout {
            padding: 0.7rem 1.5rem;
            background: linear-gradient(135deg, #f44336 0%, #e91e63 100%);
            color: white;
            border: none;
            border-radius: 8px;
            cursor: pointer;
            font-size: 0.95rem;
            font-weight: 600;
            transition: all 0.3s;
        }

        .btn-logout:hover {
            transform: translateY(-2px);
            box-shadow: 0 4px 15px rgba(244, 67, 54, 0.4);
        }

        .container {
            max-width: 1400px;
            margin: 2rem auto 4rem;
            padding: 0 2rem;
        }

        .welcome {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            padding: 2.5rem;
            border-radius: 20px;
            margin-bottom: 2rem;
            box-shadow: 0 10px 30px rgba(102, 126, 234, 0.3);
        }

        .welcome h1 {
            margin-bottom: 0.5rem;
            font-size: 2rem;
        }

        .welcome p {
            opacity: 0.95;
            font-size: 1.1rem;
        }

        .stats {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(220px, 1fr));
            gap: 1.5rem;
            margin-bottom: 2.5rem;
        }

        .stat-card {
            background: white;
            padding: 1.8rem;
            border-radius: 15px;
            box-shadow: 0 2px 15px rgba(0,0,0,0.08);
            transition: all 0.3s;
            border: 2px solid transparent;
        }

        .stat-card:hover {
            transform: translateY(-5px);
            box-shadow: 0 8px 25px rgba(0,0,0,0.15);
            border-color: #667eea;
        }

        .stat-card h3 {
            color: #666;
            font-size: 0.9rem;
            margin-bottom: 0.8rem;
            font-weight: 600;
        }

        .stat-card .value {
            font-size: 2.5rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
        }

        .stat-card .icon {
            font-size: 2rem;
            margin-bottom: 0.5rem;
        }

        .section-title {
            font-size: 1.8rem;
            color: #333;
            margin-bottom: 1.5rem;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .tests-grid {
            display: grid;
            grid-template-columns: repeat(auto-fill, minmax(320px, 1fr));
            gap: 2rem;
            margin-bottom: 3rem;
        }

        .test-card {
            background: white;
            padding: 2rem;
            border-radius: 20px;
            box-shadow: 0 2px 15px rgba(0,0,0,0.08);
            transition: all 0.3s;
            border: 2px solid transparent;
            position: relative;
            overflow: hidden;
        }

        .test-card::before {
            content: '';
            position: absolute;
            top: 0;
            left: 0;
            right: 0;
            height: 5px;
            background: linear-gradient(90deg, #667eea 0%, #764ba2 100%);
        }

        .test-card:hover {
            transform: translateY(-8px);
            box-shadow: 0 12px 35px rgba(0,0,0,0.15);
            border-color: #667eea;
        }

        .test-icon {
            font-size: 3rem;
            margin-bottom: 1rem;
        }

        .test-card h3 {
            color: #333;
            margin-bottom: 0.8rem;
            font-size: 1.3rem;
        }

        .test-card .topic {
            display: inline-block;
            padding: 0.4rem 1rem;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border-radius: 20px;
            font-size: 0.85rem;
            margin-bottom: 1rem;
            font-weight: 600;
        }

        .test-card .info {
            color: #666;
            font-size: 0.9rem;
            margin-bottom: 1rem;
            display: flex;
            flex-wrap: wrap;
            gap: 1rem;
        }

        .info-item {
            display: flex;
            align-items: center;
            gap: 0.3rem;
        }

        .test-card .description {
            color: #888;
            font-size: 0.9rem;
            line-height: 1.5;
            margin-bottom: 1.2rem;
            min-height: 40px;
        }

        .test-card .status {
            display: inline-flex;
            align-items: center;
            gap: 0.5rem;
            padding: 0.5rem 1rem;
            border-radius: 25px;
            font-size: 0.85rem;
            font-weight: 600;
            margin-bottom: 1.2rem;
        }

        .status.new {
            background: #e3f2fd;
            color: #1976d2;
        }

        .status.completed {
            background: #e8f5e9;
            color: #388e3c;
        }

        .btn-start {
            width: 100%;
            padding: 1rem;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border: none;
            border-radius: 12px;
            cursor: pointer;
            font-size: 1rem;
            font-weight: 600;
            transition: all 0.3s;
            display: flex;
            align-items: center;
            justify-content: center;
            gap: 0.5rem;
        }

        .btn-start:hover {
            transform: translateY(-2px);
            box-shadow: 0 6px 20px rgba(102, 126, 234, 0.4);
        }

        .history {
            background: white;
            padding: 2rem;
            border-radius: 20px;
            box-shadow: 0 2px 15px rgba(0,0,0,0.08);
            margin-bottom: 2rem;
        }

        .history-item {
            display: flex;
            justify-content: space-between;
            align-items: center;
            padding: 1.2rem;
            border-bottom: 1px solid #eee;
            transition: all 0.3s;
        }

        .history-item:hover {
            background: #f8f9fa;
            border-radius: 8px;
        }

        .history-item:last-child {
            border-bottom: none;
        }

        .history-info {
            flex: 1;
        }

        .history-info strong {
            color: #333;
            display: block;
            margin-bottom: 0.3rem;
        }

        .history-info small {
            color: #666;
            font-size: 0.85rem;
        }

        .history-item .score {
            font-size: 2rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
            margin-right: 1rem;
        }

        .no-history {
            text-align: center;
            color: #999;
            padding: 3rem;
            font-size: 1.1rem;
        }

        .no-history-icon {
            font-size: 4rem;
            margin-bottom: 1rem;
            opacity: 0.5;
        }

        /* ==================== FOOTER MÀU ĐEN VỚI GẠCH TÍM ==================== */
        footer {
            background: #000000;
            color: #d1d5db;
            padding: 0;
            margin-top: 4rem;
            border-top: 4px solid #8b5cf6;
        }

        .footer-content {
            max-width: 1400px;
            margin: 0 auto;
            padding: 3rem 2rem 2rem;
            display: grid;
            grid-template-columns: 2fr 1.2fr 1.2fr;
            gap: 4rem;
        }

        .footer-section h3 {
            color: #8b5cf6;
            margin-bottom: 1.2rem;
            font-size: 1.2rem;
            display: flex;
            align-items: center;
            gap: 0.5rem;
            font-weight: 700;
        }

        .footer-section p {
            margin: 0.6rem 0;
            line-height: 1.7;
            color: #d1d5db;
            font-size: 0.95rem;
        }

        .footer-section p strong {
            color: #8b5cf6;
            font-weight: 600;
        }

        .footer-section a {
            display: block;
            color: #60a5fa;
            text-decoration: none;
            margin: 0.6rem 0;
            transition: all 0.3s;
            font-size: 0.95rem;
        }

        .footer-section a:hover {
            color: #93c5fd;
            padding-left: 8px;
        }

        .social-links {
            display: flex;
            gap: 1rem;
            margin-top: 1.2rem;
        }

        .social-links a {
            width: 42px;
            height: 42px;
            background: #8b5cf6;
            border-radius: 50%;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 1.2rem;
            transition: all 0.3s;
            padding-left: 0;
        }

        .social-links a:hover {
            background: #a78bfa;
            transform: translateY(-4px);
            box-shadow: 0 4px 12px rgba(139, 92, 246, 0.5);
            padding-left: 0;
        }

        .footer-bottom {
            text-align: center;
            padding: 1.5rem 2rem;
            border-top: 1px solid #1f2937;
            color: #9ca3af;
            background: #0a0a0a;
        }

        .footer-bottom p {
            margin: 0.3rem 0;
            font-size: 0.9rem;
        }

        .heart {
            color: #ef4444;
            animation: heartbeat 1.5s ease-in-out infinite;
            display: inline-block;
        }

        @keyframes heartbeat {
            0%, 100% { transform: scale(1); }
            25% { transform: scale(1.15); }
            50% { transform: scale(1); }
            75% { transform: scale(1.1); }
        }

        @media (max-width: 1024px) {
            .footer-content {
                grid-template-columns: 1fr 1fr;
                gap: 3rem;
            }

            .footer-section:first-child {
                grid-column: 1 / -1;
            }
        }

        @media (max-width: 768px) {
            .container {
                padding: 0 1rem;
            }

            .tests-grid {
                grid-template-columns: 1fr;
            }

            .stats {
                grid-template-columns: repeat(2, 1fr);
            }

            .user-info {
                gap: 0.8rem;
            }

            .user-name span:first-child {
                display: none;
            }

            .footer-content {
                grid-template-columns: 1fr;
                gap: 2.5rem;
                padding: 2.5rem 1.5rem 1.5rem;
            }

            .footer-section:first-child {
                grid-column: 1;
            }

            .social-links {
                justify-content: flex-start;
            }
        }
    </style>
</head>
<body>
    <header>
        <nav>
            <div class="logo">
                <span>📚</span>
                <span>IELTS Reading Pro</span>
            </div>
            <div class="user-info">
                <span class="user-name">
                    <span>👤</span>
                    <span id="userName"></span>
                </span>
                <button class="btn-logout" onclick="logout()">🚪 Đăng xuất</button>
            </div>
        </nav>
    </header>

    <div class="container">
        <div class="welcome">
            <h1 id="welcomeText"></h1>
            <p>Sẵn sàng chinh phục IELTS Reading? Chọn bài test và bắt đầu ngay! 🚀</p>
        </div>

        <div class="stats">
            <div class="stat-card">
                <div class="icon">📝</div>
                <h3>Tổng bài đã làm</h3>
                <div class="value" id="totalTests">0</div>
            </div>
            <div class="stat-card">
                <div class="icon">📊</div>
                <h3>Điểm trung bình</h3>
                <div class="value" id="avgScore">0.0</div>
            </div>
            <div class="stat-card">
                <div class="icon">🎯</div>
                <h3>Độ chính xác</h3>
                <div class="value" id="accuracy">0%</div>
            </div>
            <div class="stat-card">
                <div class="icon">🏆</div>
                <h3>Điểm cao nhất</h3>
                <div class="value" id="bestScore">0</div>
            </div>
        </div>

        <h2 class="section-title">
            <span>📚</span>
            <span>Danh sách bài test</span>
        </h2>
        <div class="tests-grid" id="testsGrid"></div>

        <h2 class="section-title">
            <span>📊</span>
            <span>Lịch sử làm bài</span>
        </h2>
        <div class="history" id="historyList"></div>
    </div>

    <!-- ==================== FOOTER MÀU ĐEN VỚI GẠCH TÍM ==================== -->
    <footer>
        <div class="footer-content">
            <!-- Phần giới thiệu project -->
            <div class="footer-section">
                <h3>📚 IELTS Reading Pro</h3>
                <p>Nền tảng luyện thi IELTS Reading online hoàn toàn miễn phí với 5 bài test thực chiến.</p>
                <p style="margin-top: 1.2rem;">
                    <strong>Dự án Tin học 12</strong><br>
                    Trường THPT Võ Trường Toản<br>
                    Năm học 2025-2026
                </p>
            </div>

            <!-- Phần thông tin nhóm -->
            <div class="footer-section">
                <h3>👥 Thành viên nhóm</h3>
                <p><strong>Nhóm trưởng:</strong> Nguyễn Lê Anh Khoa</p>
                <p style="margin-top: 0.8rem;"><strong>Thành viên:</strong></p>
                <p>Đoàn Phùng Hải Lân</p>
                <p>Lê Nhật Nam</p>
                <p>Nguyễn Hữu Phúc</p>
                <p>Lê Trần Việt Tiến</p>
            </div>

            <!-- Phần liên hệ -->
            <div class="footer-section">
                <h3>📞 Liên hệ</h3>
                <a href="mailto:student232330@ptnk.edu.vn">✉️ student232330@ptnk.edu.vn</a>
                <a href="tel:+84843927xxx">📱 0843927xxx</a>
                <a href="#" style="pointer-events: none; opacity: 0.7;">📍 TP Hồ Chí Minh, Việt Nam</a>

                <!-- Social media links -->
                <div class="social-links">
                    <a href="#" title="Facebook">📘</a>
                    <a href="#" title="YouTube">▶️</a>
                    <a href="#" title="Instagram">📷</a>
                    <a href="#" title="Twitter">🐦</a>
                </div>
            </div>
        </div>

        <!-- Copyright -->
        <div class="footer-bottom">
            <p><strong>© 2025 IELTS Reading Pro</strong> - Dự án Tin học 12 - Trường THPT Võ Trường Toản</p>
            <p>Made with <span class="heart">❤️</span> for IELTS learners</p>
        </div>
    </footer>

    <script>
        // Kiểm tra đăng nhập
        const currentUser = JSON.parse(localStorage.getItem('currentUser'));
        if (!currentUser) {
            window.location.href = 'login.html';
        }

        // Hiển thị tên user
        document.getElementById('userName').textContent = currentUser.fullname;
        document.getElementById('welcomeText').textContent = `Xin chào, ${currentUser.fullname}! 👋`;

        // Dữ liệu 5 bài test
        const tests = [
            {
                id: 1,
                title: "Test 1: Climate Change",
                topic: "Environment 🌍",
                icon: "🌡️",
                difficulty: "Medium",
                passages: 1,
                questions: 8,
                time: 60,
                description: "Tác động của biến đổi khí hậu đến môi trường và con người"
            },
            {
                id: 2,
                title: "Test 2: Artificial Intelligence",
                topic: "Technology 💻",
                icon: "🤖",
                difficulty: "Hard",
                passages: 1,
                questions: 8,
                time: 60,
                description: "Trí tuệ nhân tạo và ảnh hưởng của nó trong cuộc sống hiện đại"
            },
            {
                id: 3,
                title: "Test 3: Ancient Rome",
                topic: "History 📜",
                icon: "🏛️",
                difficulty: "Medium",
                passages: 1,
                questions: 8,
                time: 60,
                description: "Đế chế La Mã cổ đại và di sản văn hóa của nó"
            },
            {
                id: 4,
                title: "Test 4: Modern Medicine",
                topic: "Health 🏥",
                icon: "⚕️",
                difficulty: "Easy",
                passages: 1,
                questions: 8,
                time: 60,
                description: "Những tiến bộ của y học hiện đại trong thế kỷ 21"
            },
            {
                id: 5,
                title: "Test 5: Space Exploration",
                topic: "Science 🔬",
                icon: "🚀",
                difficulty: "Hard",
                passages: 1,
                questions: 8,
                time: 60,
                description: "Khám phá vũ trụ và tìm kiếm sự sống ngoài Trái Đất"
            }
        ];

        localStorage.setItem('tests', JSON.stringify(tests));

        function getUserHistory() {
            const users = JSON.parse(localStorage.getItem('users') || '[]');
            const user = users.find(u => u.id === currentUser.id);
            return user ? user.testHistory || [] : [];
        }

        function calculateStats() {
            const history = getUserHistory();
            if (history.length === 0) {
                return { totalTests: 0, avgScore: 0, accuracy: 0, bestScore: 0 };
            }
            const totalTests = history.length;
            const totalScore = history.reduce((sum, test) => sum + test.score, 0);
            const avgScore = (totalScore / totalTests).toFixed(1);
            const totalCorrect = history.reduce((sum, test) => sum + test.correct, 0);
            const totalQuestions = history.reduce((sum, test) => sum + test.total, 0);
            const accuracy = Math.round((totalCorrect / totalQuestions) * 100);
            const bestScore = Math.max(...history.map(test => test.score));
            return { totalTests, avgScore, accuracy, bestScore };
        }

        const stats = calculateStats();
        document.getElementById('totalTests').textContent = stats.totalTests;
        document.getElementById('avgScore').textContent = stats.avgScore;
        document.getElementById('accuracy').textContent = stats.accuracy + '%';
        document.getElementById('bestScore').textContent = stats.bestScore;

        const history = getUserHistory();
        const testsGrid = document.getElementById('testsGrid');

        tests.forEach(test => {
            const completed = history.find(h => h.testId === test.id);
            const card = document.createElement('div');
            card.className = 'test-card';
            card.innerHTML = `
                <div class="test-icon">${test.icon}</div>
                <h3>${test.title}</h3>
                <div class="topic">${test.topic}</div>
                <div class="info">
                    <div class="info-item">⏱️ ${test.time} phút</div>
                    <div class="info-item">📝 ${test.questions} câu hỏi</div>
                    <div class="info-item">🎯 ${test.difficulty}</div>
                </div>
                <div class="description">${test.description}</div>
                <div class="status ${completed ? 'completed' : 'new'}">
                    ${completed ? '✅ Đã làm - Điểm: ' + completed.score + '/' + completed.total : '🆕 Chưa làm'}
                </div>
                <button class="btn-start" onclick="startTest(${test.id})">
                    ${completed ? '🔄 Làm lại' : '▶️ Bắt đầu'}
                </button>
            `;
            testsGrid.appendChild(card);
        });

        const historyList = document.getElementById('historyList');
        if (history.length === 0) {
            historyList.innerHTML = `
                <div class="no-history">
                    <div class="no-history-icon">📭</div>
                    <div>Chưa có lịch sử làm bài</div>
                    <div style="margin-top: 0.5rem; color: #bbb;">Hãy bắt đầu test đầu tiên của bạn! 🚀</div>
                </div>
            `;
        } else {
            history.slice().reverse().forEach(item => {
                const test = tests.find(t => t.id === item.testId);
                const percentage = Math.round((item.correct / item.total) * 100);
                const historyItem = document.createElement('div');
                historyItem.className = 'history-item';
                historyItem.innerHTML = `
                    <div class="history-info">
                        <strong>${test.icon} ${test.title}</strong>
                        <small>
                            🕒 ${new Date(item.date).toLocaleString('vi-VN')} |
                            ✅ ${item.correct}/${item.total} đúng (${percentage}%)
                        </small>
                    </div>
                    <div class="score">${item.score}</div>
                `;
                historyList.appendChild(historyItem);
            });
        }

        function startTest(testId) {
            localStorage.setItem('currentTestId', testId);
            window.location.href = 'test.html';
        }

        function logout() {
            if (confirm('Bạn có chắc muốn đăng xuất?')) {
                localStorage.removeItem('currentUser');
                window.location.href = 'index.html';
            }
        }
    </script>
</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Test - THIẾT KẾ TỐI ƯU
Giải pháp: Passage STICKY + scroll riêng | Questions scroll bình thường
→ Làm câu nào cũng nhìn thấy bài đọc!
"""

import os

os.chdir('/content/ielts_reading_pro')

test_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IELTS Reading Test</title>

    <style>
        /* ==================== RESET ==================== */
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: #f5f7fa;
            line-height: 1.6;
        }

        /* ==================== HEADER STICKY ==================== */
        header {
            background: white;
            padding: 1rem 2rem;
            box-shadow: 0 2px 15px rgba(0,0,0,0.1);
            position: sticky;
            top: 0;
            z-index: 100;
        }

        nav {
            display: flex;
            justify-content: space-between;
            align-items: center;
            max-width: 1600px;
            margin: 0 auto;
        }

        .logo {
            font-size: 1.3rem;
            font-weight: bold;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            -webkit-background-clip: text;
            -webkit-text-fill-color: transparent;
        }

        /* ==================== TIMER ==================== */
        .timer {
            font-size: 1.5rem;
            font-weight: bold;
            color: #667eea;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .timer.warning { color: #ff9800; animation: pulse 1s infinite; }
        .timer.danger { color: #f44336; }

        @keyframes pulse {
            0%, 100% { transform: scale(1); }
            50% { transform: scale(1.05); }
        }

        /* ==================== CONTAINER 2 CỘT ==================== */
        .container {
            max-width: 1600px;
            margin: 2rem auto;
            padding: 0 2rem 2rem 2rem;
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 2rem;
            align-items: start;
        }

        /* ==================== PASSAGE - STICKY VÀ CÓ SCROLL RIÊNG ==================== */
        .passage-section {
            background: white;
            border-radius: 15px;
            box-shadow: 0 2px 15px rgba(0,0,0,0.08);
            position: sticky;
            top: calc(70px + 2rem); /* Header height + margin */
            max-height: calc(100vh - 100px);
            overflow: hidden;
            display: flex;
            flex-direction: column;
        }

        .passage-header {
            padding: 1.5rem 2rem;
            border-bottom: 2px solid #f0f0f0;
            background: white;
            border-radius: 15px 15px 0 0;
        }

        .passage-title {
            font-size: 1.5rem;
            color: #333;
            display: flex;
            align-items: center;
            gap: 0.5rem;
            margin: 0;
        }

        .passage-content {
            padding: 2rem;
            overflow-y: auto;
            flex: 1;
        }

        .passage-text {
            line-height: 1.8;
            color: #444;
            font-size: 1.05rem;
        }

        .passage-text p {
            margin-bottom: 1.2rem;
            text-align: justify;
        }

        /* Custom scrollbar cho passage */
        .passage-content::-webkit-scrollbar {
            width: 8px;
        }

        .passage-content::-webkit-scrollbar-track {
            background: #f1f1f1;
            border-radius: 10px;
        }

        .passage-content::-webkit-scrollbar-thumb {
            background: #667eea;
            border-radius: 10px;
        }

        .passage-content::-webkit-scrollbar-thumb:hover {
            background: #764ba2;
        }

        /* ==================== QUESTIONS - SCROLL BÌNH THƯỜNG ==================== */
        .questions-section {
            background: white;
            padding: 2rem;
            border-radius: 15px;
            box-shadow: 0 2px 15px rgba(0,0,0,0.08);
            min-height: 100vh; /* Đủ cao để scroll */
        }

        .questions-header {
            margin-bottom: 1.5rem;
            padding-bottom: 1rem;
            border-bottom: 2px solid #f0f0f0;
        }

        .questions-section h2 {
            font-size: 1.5rem;
            color: #333;
            display: flex;
            align-items: center;
            gap: 0.5rem;
            margin-bottom: 1rem;
        }

        /* ==================== PROGRESS BAR ==================== */
        .progress {
            background: #e0e0e0;
            height: 8px;
            border-radius: 4px;
            margin-bottom: 1rem;
            overflow: hidden;
        }

        .progress-bar {
            height: 100%;
            background: linear-gradient(90deg, #667eea 0%, #764ba2 100%);
            transition: width 0.3s;
        }

        /* ==================== QUESTION CARD ==================== */
        .question {
            margin-bottom: 2rem;
            padding: 1.5rem;
            background: #f8f9fa;
            border-radius: 12px;
            border-left: 4px solid #667eea;
            animation: fadeIn 0.3s ease-out;
        }

        @keyframes fadeIn {
            from { opacity: 0; transform: translateY(20px); }
            to { opacity: 1; transform: translateY(0); }
        }

        .question-text {
            font-weight: 600;
            color: #333;
            margin-bottom: 1rem;
            font-size: 1.05rem;
        }

        /* ==================== OPTIONS ==================== */
        .options {
            display: flex;
            flex-direction: column;
            gap: 0.8rem;
        }

        .option {
            padding: 1rem 1.2rem;
            background: white;
            border: 2px solid #e0e0e0;
            border-radius: 8px;
            cursor: pointer;
            transition: all 0.3s;
            display: flex;
            align-items: center;
            gap: 0.8rem;
        }

        .option:hover {
            border-color: #667eea;
            background: #f0f4ff;
            transform: translateX(4px);
        }

        .option input[type="radio"] {
            width: 20px;
            height: 20px;
            cursor: pointer;
            accent-color: #667eea;
        }

        .option.selected {
            border-color: #667eea;
            background: #e8f0fe;
            font-weight: 500;
            box-shadow: 0 2px 8px rgba(102, 126, 234, 0.2);
        }

        /* ==================== SUBMIT SECTION ==================== */
        .submit-section {
            text-align: center;
            margin-top: 3rem;
            padding: 2rem 0;
            border-top: 2px solid #f0f0f0;
        }

        .btn-submit {
            padding: 1.2rem 3rem;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border: none;
            border-radius: 12px;
            font-size: 1.1rem;
            font-weight: 600;
            cursor: pointer;
            transition: all 0.3s;
            box-shadow: 0 4px 15px rgba(102, 126, 234, 0.3);
        }

        .btn-submit:hover {
            transform: translateY(-2px);
            box-shadow: 0 8px 25px rgba(102, 126, 234, 0.4);
        }

        .btn-submit:active {
            transform: translateY(0);
        }

        /* ==================== SCROLL INDICATOR - CHỈ DẪN SCROLL ==================== */
        .scroll-hint {
            text-align: center;
            padding: 1rem;
            color: #888;
            font-size: 0.9rem;
            display: flex;
            align-items: center;
            justify-content: center;
            gap: 0.5rem;
        }

        .scroll-hint.hidden {
            opacity: 0;
            pointer-events: none;
        }

        /* ==================== RESPONSIVE ==================== */
        @media (max-width: 1200px) {
            .container {
                grid-template-columns: 1fr;
                gap: 1.5rem;
            }

            .passage-section {
                position: relative;
                top: 0;
                max-height: 500px;
            }

            nav {
                flex-direction: column;
                gap: 1rem;
            }

            .timer {
                font-size: 1.2rem;
            }
        }

        @media (max-width: 768px) {
            .container {
                padding: 0 1rem 1rem 1rem;
                margin: 1rem auto;
            }

            .passage-section,
            .questions-section {
                padding: 1.5rem;
            }

            .passage-title,
            .questions-section h2 {
                font-size: 1.3rem;
            }
        }

        /* ==================== GLOBAL SCROLLBAR ==================== */
        ::-webkit-scrollbar {
            width: 10px;
        }

        ::-webkit-scrollbar-track {
            background: #f1f1f1;
        }

        ::-webkit-scrollbar-thumb {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            border-radius: 10px;
        }

        ::-webkit-scrollbar-thumb:hover {
            background: linear-gradient(135deg, #764ba2 0%, #667eea 100%);
        }

        /* ==================== READING TIPS ==================== */
        .reading-tips {
            background: #fff8e1;
            border-left: 4px solid #ffc107;
            padding: 1rem;
            margin: 1rem 0;
            border-radius: 8px;
            font-size: 0.95rem;
            color: #666;
        }

        .reading-tips strong {
            color: #f57c00;
        }
    </style>
</head>
<body>
    <!-- ==================== HEADER ==================== -->
    <header>
        <nav>
            <div class="logo" id="testTitle">📚 Loading...</div>
            <div class="timer" id="timer">⏱️ 60:00</div>
        </nav>
    </header>

    <!-- ==================== CONTAINER ==================== -->
    <div class="container">
        <!-- ==================== PASSAGE SECTION - STICKY ==================== -->
        <div class="passage-section">
            <div class="passage-header">
                <h1 class="passage-title">📖 Reading Passage</h1>
            </div>
            <div class="passage-content">
                <div class="reading-tips">
                    <strong>💡 Tip:</strong> Passage này sẽ luôn hiển thị khi bạn scroll xuống làm câu hỏi!
                </div>
                <div class="passage-text" id="passageText">
                    <p>Loading passage...</p>
                </div>
            </div>
        </div>

        <!-- ==================== QUESTIONS SECTION - SCROLL BÌNH THƯỜNG ==================== -->
        <div class="questions-section">
            <div class="questions-header">
                <h2>❓ Questions (<span id="questionCount">0</span>/<span id="totalCount">0</span>)</h2>

                <div class="progress">
                    <div class="progress-bar" id="progressBar" style="width: 0%"></div>
                </div>
            </div>

            <div id="questionsContainer"></div>

            <!-- SUBMIT BUTTON -->
            <div class="submit-section">
                <button class="btn-submit" id="submitBtn" onclick="submitTest()">
                    ✅ Nộp bài
                </button>
            </div>

            <!-- SCROLL HINT -->
            <div class="scroll-hint" id="scrollHint">
                ⬆️ Bạn đã đến cuối trang - Scroll lên để xem lại câu hỏi
            </div>
        </div>
    </div>

    <!-- ==================== LOAD TEST DATA ==================== -->
    <script src="test-data.js"></script>

    <!-- ==================== JAVASCRIPT ==================== -->
    <script>
        const currentTestId = parseInt(localStorage.getItem('currentTestId')) || 1;
        const testData = TEST_DATA[currentTestId];

        if (!testData) {
            alert('Không tìm thấy dữ liệu test!');
            window.location.href = 'dashboard.html';
        }

        document.getElementById('testTitle').textContent = testData.title;
        document.getElementById('passageText').innerHTML = testData.passage.text;

        const questions = testData.questions;
        document.getElementById('questionCount').textContent = '0';
        document.getElementById('totalCount').textContent = questions.length;

        const container = document.getElementById('questionsContainer');
        questions.forEach(q => {
            const questionDiv = document.createElement('div');
            questionDiv.className = 'question';
            questionDiv.innerHTML = `
                <div class="question-text">${q.text}</div>
                <div class="options">
                    ${q.options.map((opt, idx) => `
                        <label class="option" onclick="selectOption(${q.id}, ${idx})">
                            <input type="radio" name="q${q.id}" value="${idx}">
                            <span>${String.fromCharCode(65 + idx)}. ${opt}</span>
                        </label>
                    `).join('')}
                </div>
            `;
            container.appendChild(questionDiv);
        });

        const userAnswers = {};

        function selectOption(qId, optionIdx) {
            userAnswers[qId] = optionIdx;

            const options = document.querySelectorAll(`input[name="q${qId}"]`);
            options.forEach((opt, idx) => {
                opt.parentElement.classList.toggle('selected', idx === optionIdx);
            });

            const answered = Object.keys(userAnswers).length;
            document.getElementById('questionCount').textContent = answered;
            const progress = (answered / questions.length) * 100;
            document.getElementById('progressBar').style.width = progress + '%';
        }

        let timeLeft = 3600;
        const timerEl = document.getElementById('timer');

        const timerInterval = setInterval(() => {
            timeLeft--;
            const minutes = Math.floor(timeLeft / 60);
            const seconds = timeLeft % 60;
            timerEl.textContent = `⏱️ ${minutes}:${seconds.toString().padStart(2, '0')}`;

            if (timeLeft <= 300) timerEl.classList.add('warning');
            if (timeLeft <= 60) timerEl.classList.add('danger');

            if (timeLeft <= 0) {
                clearInterval(timerInterval);
                alert('⏰ Hết giờ! Tự động nộp bài.');
                submitTest();
            }
        }, 1000);

        function submitTest() {
            const answered = Object.keys(userAnswers).length;

            if (answered < questions.length) {
                if (!confirm(`Bạn mới trả lời ${answered}/${questions.length} câu. Nộp bài luôn?`)) {
                    return;
                }
            }

            clearInterval(timerInterval);

            let correct = 0;
            questions.forEach(q => {
                if (userAnswers[q.id] === q.correct) {
                    correct++;
                }
            });

            const score = correct;
            const timeUsed = 3600 - timeLeft;

            const currentUser = JSON.parse(localStorage.getItem('currentUser'));
            const users = JSON.parse(localStorage.getItem('users') || '[]');
            const userIndex = users.findIndex(u => u.id === currentUser.id);

            if (userIndex !== -1) {
                if (!users[userIndex].testHistory) {
                    users[userIndex].testHistory = [];
                }

                users[userIndex].testHistory.push({
                    testId: currentTestId,
                    score: score,
                    total: questions.length,
                    correct: correct,
                    timeUsed: timeUsed,
                    date: new Date().toISOString()
                });

                localStorage.setItem('users', JSON.stringify(users));
                localStorage.setItem('currentUser', JSON.stringify(users[userIndex]));
            }

            localStorage.setItem('testResult', JSON.stringify({
                testId: currentTestId,
                testTitle: testData.title,
                score: score,
                total: questions.length,
                correct: correct,
                timeUsed: timeUsed,
                answers: userAnswers,
                questions: questions
            }));

            window.location.href = 'result.html';
        }

        window.addEventListener('beforeunload', (e) => {
            e.preventDefault();
            e.returnValue = '';
        });

        // Ẩn scroll hint khi scroll xuống
        let scrollTimeout;
        window.addEventListener('scroll', () => {
            const scrollHint = document.getElementById('scrollHint');
            clearTimeout(scrollTimeout);
            scrollTimeout = setTimeout(() => {
                const scrolled = window.pageYOffset + window.innerHeight;
                const total = document.body.scrollHeight;
                if (scrolled >= total - 100) {
                    scrollHint.style.opacity = '1';
                } else {
                    scrollHint.style.opacity = '0';
                }
            }, 100);
        });
    </script>
</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice - Result.html với Footer GIỐNG Y CHANG hình mẫu
"""

import os

os.chdir('/content/ielts_reading_pro')

result_html = '''<!DOCTYPE html>
<html lang="vi">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Kết quả Test - IELTS Reading Pro</title>
    <style>
        /* ==================== RESET CSS ==================== */
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        /* ==================== BODY ==================== */
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            min-height: 100vh;
            padding: 2rem 2rem 0 2rem; /* BỎ PADDING BOTTOM */
            display: flex;
            flex-direction: column;
        }

        .container {
            max-width: 900px;
            margin: 0 auto;
            flex: 1;
        }

        /* ==================== RESULT CARD ==================== */
        .result-card {
            background: white;
            border-radius: 25px;
            padding: 3rem;
            box-shadow: 0 25px 70px rgba(0,0,0,0.4);
            animation: slideUp 0.6s ease-out;
        }

        @keyframes slideUp {
            from {
                opacity: 0;
                transform: translateY(50px);
            }
            to {
                opacity: 1;
                transform: translateY(0);
            }
        }

        /* ==================== HEADER ==================== */
        .header {
            text-align: center;
            margin-bottom: 2.5rem;
        }

        .trophy {
            font-size: 5rem;
            margin-bottom: 1rem;
            animation: bounce 1s ease-in-out infinite;
        }

        @keyframes bounce {
            0%, 100% { transform: translateY(0); }
            50% { transform: translateY(-20px); }
        }

        .header h1 {
            font-size: 2.5rem;
            color: #333;
            margin-bottom: 0.5rem;
        }

        .header p {
            font-size: 1.2rem;
            color: #666;
        }

        /* ==================== SCORE SECTION ==================== */
        .score-section {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
            gap: 1.5rem;
            margin-bottom: 2.5rem;
        }

        .score-box {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            padding: 2rem;
            border-radius: 15px;
            text-align: center;
            box-shadow: 0 8px 20px rgba(102, 126, 234, 0.3);
        }

        .score-box h3 {
            font-size: 0.9rem;
            opacity: 0.9;
            margin-bottom: 0.8rem;
            text-transform: uppercase;
            letter-spacing: 1px;
        }

        .score-box .value {
            font-size: 3rem;
            font-weight: bold;
        }

        /* ==================== PERFORMANCE ==================== */
        .performance {
            background: #f8f9fa;
            padding: 2rem;
            border-radius: 15px;
            margin-bottom: 2rem;
        }

        .performance h2 {
            color: #333;
            margin-bottom: 1.5rem;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .progress-item {
            margin-bottom: 1.5rem;
        }

        .progress-label {
            display: flex;
            justify-content: space-between;
            margin-bottom: 0.5rem;
            font-weight: 600;
            color: #555;
        }

        .progress-bar-container {
            background: #e0e0e0;
            height: 12px;
            border-radius: 6px;
            overflow: hidden;
        }

        .progress-bar {
            height: 100%;
            background: linear-gradient(90deg, #667eea 0%, #764ba2 100%);
            border-radius: 6px;
            transition: width 1s ease-out;
        }

        /* ==================== ANSWERS SECTION ==================== */
        .answers-section {
            margin-bottom: 2rem;
        }

        .answers-section h2 {
            color: #333;
            margin-bottom: 1.5rem;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .answer-item {
            background: #f8f9fa;
            padding: 1.5rem;
            border-radius: 12px;
            margin-bottom: 1rem;
            border-left: 5px solid #ccc;
        }

        .answer-item.correct {
            border-left-color: #4caf50;
            background: #e8f5e9;
        }

        .answer-item.incorrect {
            border-left-color: #f44336;
            background: #ffebee;
        }

        .answer-item .question-number {
            font-weight: bold;
            color: #333;
            margin-bottom: 0.5rem;
            font-size: 1.1rem;
        }

        .answer-item .question-text {
            color: #555;
            margin-bottom: 0.8rem;
        }

        .answer-details {
            display: grid;
            gap: 0.5rem;
            font-size: 0.95rem;
        }

        .answer-details div {
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .answer-details .correct-answer {
            color: #4caf50;
            font-weight: 600;
        }

        .answer-details .your-answer {
            color: #f44336;
            font-weight: 600;
        }

        .answer-details .correct-user-answer {
            color: #4caf50;
            font-weight: 600;
        }

        /* ==================== BUTTONS ==================== */
        .buttons {
            display: flex;
            gap: 1rem;
            justify-content: center;
            flex-wrap: wrap;
        }

        .btn {
            padding: 1rem 2rem;
            border: none;
            border-radius: 12px;
            font-size: 1rem;
            font-weight: 600;
            cursor: pointer;
            transition: all 0.3s;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .btn-primary {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
        }

        .btn-primary:hover {
            transform: translateY(-2px);
            box-shadow: 0 8px 20px rgba(102, 126, 234, 0.4);
        }

        .btn-secondary {
            background: white;
            color: #667eea;
            border: 2px solid #667eea;
        }

        .btn-secondary:hover {
            background: #667eea;
            color: white;
            transform: translateY(-2px);
        }

        /* ==================== FEEDBACK ==================== */
        .feedback {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            padding: 2rem;
            border-radius: 15px;
            margin-bottom: 2rem;
            text-align: center;
        }

        .feedback h3 {
            font-size: 1.5rem;
            margin-bottom: 1rem;
        }

        .feedback p {
            font-size: 1.1rem;
            opacity: 0.95;
            line-height: 1.6;
        }

        /* ==================== FOOTER - GIỐNG Y CHANG HÌNH MẪU ==================== */
        footer {
            background: #000000;
            color: #ffffff;
            padding: 3rem 2rem 1.5rem 2rem;
            margin-top: 3rem;
            border-radius: 0;
            width: 100vw;
            margin-left: calc(-50vw + 50%); /* CENTER FULL WIDTH */
            position: relative;
        }

        /* Viền tím trên cùng */
        footer::before {
            content: '';
            position: absolute;
            top: 0;
            left: 0;
            right: 0;
            height: 4px;
            background: linear-gradient(90deg, #a855f7, #ec4899, #8b5cf6);
        }

        .footer-content {
            max-width: 1400px;
            margin: 0 auto;
            display: grid;
            grid-template-columns: repeat(3, 1fr);
            gap: 4rem;
            padding: 0 3rem;
            margin-bottom: 2.5rem;
        }

        /* ==================== CỘT 1: IELTS Reading Pro ==================== */
        .footer-column h3 {
            color: #a855f7;
            font-size: 1.4rem;
            margin-bottom: 1.5rem;
            font-weight: 700;
            display: flex;
            align-items: center;
            gap: 0.5rem;
        }

        .footer-column p {
            color: #d1d5db;
            line-height: 1.8;
            margin-bottom: 0.5rem;
            font-size: 0.95rem;
        }

        .footer-column .project-info {
            margin-top: 1.5rem;
        }

        .footer-column .project-info strong {
            color: #a855f7;
            display: block;
            margin-bottom: 0.3rem;
            font-size: 1rem;
        }

        /* ==================== CỘT 2: Thành viên nhóm ==================== */
        .team-list {
            list-style: none;
        }

        .team-list li {
            color: #d1d5db;
            margin-bottom: 0.8rem;
            font-size: 0.95rem;
            line-height: 1.6;
        }

        .team-list .team-leader {
            color: #a855f7;
            font-weight: 600;
        }

        .team-list .label {
            color: #a855f7;
            font-weight: 600;
            margin-right: 0.3rem;
        }

        /* ==================== CỘT 3: Liên hệ ==================== */
        .contact-list {
            list-style: none;
        }

        .contact-list li {
            display: flex;
            align-items: center;
            gap: 0.8rem;
            color: #d1d5db;
            margin-bottom: 1rem;
            font-size: 0.95rem;
            transition: all 0.3s;
        }

        .contact-list li:hover {
            color: #a855f7;
            transform: translateX(5px);
        }

        .contact-list a {
            color: #d1d5db;
            text-decoration: none;
            transition: all 0.3s;
        }

        .contact-list a:hover {
            color: #a855f7;
        }

        .contact-icon {
            font-size: 1.2rem;
        }

        /* SOCIAL LINKS - 4 icons tròn màu gradient */
        .social-links {
            display: flex;
            gap: 1rem;
            margin-top: 1.5rem;
        }

        .social-links a {
            width: 50px;
            height: 50px;
            border-radius: 50%;
            background: linear-gradient(135deg, #a855f7, #ec4899);
            color: white;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 1.5rem;
            transition: all 0.3s;
            text-decoration: none;
        }

        .social-links a:hover {
            transform: translateY(-5px) scale(1.1);
            box-shadow: 0 8px 25px rgba(168, 85, 247, 0.6);
        }

        /* ==================== FOOTER BOTTOM - COPYRIGHT ==================== */
        .footer-bottom {
            text-align: center;
            padding-top: 2rem;
            border-top: 1px solid #333;
            color: #9ca3af;
            font-size: 0.9rem;
            max-width: 1400px;
            margin: 0 auto;
            padding-left: 3rem;
            padding-right: 3rem;
        }

        .footer-bottom p {
            margin-bottom: 0.5rem;
            line-height: 1.8;
        }

        .heart {
            color: #ff6b6b;
            animation: heartbeat 1.5s ease-in-out infinite;
        }

        @keyframes heartbeat {
            0%, 100% { transform: scale(1); }
            25% { transform: scale(1.2); }
            50% { transform: scale(1); }
        }

        /* ==================== RESPONSIVE ==================== */
        @media (max-width: 768px) {
            body {
                padding: 1rem 1rem 0 1rem; /* BỎ PADDING BOTTOM */
            }

            .result-card {
                padding: 2rem 1.5rem;
            }

            .header h1 {
                font-size: 2rem;
            }

            .trophy {
                font-size: 3.5rem;
            }

            .score-box .value {
                font-size: 2.5rem;
            }

            .buttons {
                flex-direction: column;
            }

            .btn {
                width: 100%;
                justify-content: center;
            }

            footer {
                margin-left: calc(-50vw + 50%);
                padding: 2rem 1rem 1rem 1rem;
            }

            .footer-content {
                grid-template-columns: 1fr;
                gap: 2.5rem;
                padding: 0 1rem;
            }

            .footer-bottom {
                padding-left: 1rem;
                padding-right: 1rem;
            }

            .social-links {
                justify-content: center;
            }
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="result-card">
            <!-- HEADER -->
            <div class="header">
                <div class="trophy" id="trophy">🏆</div>
                <h1 id="resultTitle">Hoàn thành xuất sắc!</h1>
                <p id="testName">Test 2: Artificial Intelligence</p>
            </div>

            <!-- SCORE SECTION -->
            <div class="score-section">
                <div class="score-box">
                    <h3>Điểm số</h3>
                    <div class="value" id="score">0/8</div>
                </div>
                <div class="score-box">
                    <h3>Độ chính xác</h3>
                    <div class="value" id="accuracy">0%</div>
                </div>
                <div class="score-box">
                    <h3>Thời gian</h3>
                    <div class="value" id="timeUsed">0:00</div>
                </div>
            </div>

            <!-- FEEDBACK -->
            <div class="feedback" id="feedback"></div>

            <!-- PERFORMANCE -->
            <div class="performance">
                <h2>📊 Phân tích chi tiết</h2>
                <div class="progress-item">
                    <div class="progress-label">
                        <span>Câu đúng</span>
                        <span id="correctCount">0/8</span>
                    </div>
                    <div class="progress-bar-container">
                        <div class="progress-bar" id="correctBar" style="width: 0%"></div>
                    </div>
                </div>
                <div class="progress-item">
                    <div class="progress-label">
                        <span>Câu sai</span>
                        <span id="incorrectCount">0/8</span>
                    </div>
                    <div class="progress-bar-container">
                        <div class="progress-bar" id="incorrectBar" style="width: 0%; background: linear-gradient(90deg, #f44336 0%, #e91e63 100%);"></div>
                    </div>
                </div>
            </div>

            <!-- ANSWERS DETAIL -->
            <div class="answers-section">
                <h2>📝 Chi tiết từng câu</h2>
                <div id="answersContainer"></div>
            </div>

            <!-- BUTTONS -->
            <div class="buttons">
                <button class="btn btn-primary" onclick="window.location.href='dashboard.html'">
                    <span>🏠</span>
                    <span>Về Dashboard</span>
                </button>
                <button class="btn btn-secondary" onclick="retakeTest()">
                    <span>🔄</span>
                    <span>Làm lại Test</span>
                </button>
            </div>
        </div>
    </div>

    <!-- ==================== FOOTER - GIỐNG Y CHANG HÌNH MẪU ==================== -->
    <footer>
        <div class="footer-content">
            <!-- CỘT 1: IELTS Reading Pro -->
            <div class="footer-column">
                <h3>📚 IELTS Reading Pro</h3>
                <p>Nền tảng luyện thi IELTS Reading online hoàn toàn miễn phí với 5 bài test thực chiến.</p>

                <div class="project-info">
                    <strong>Dự án Tin học 12</strong>
                    <p>Trường THPT Võ Trường Toản</p>
                    <p>Năm học 2025-2026</p>
                </div>
            </div>

            <!-- CỘT 2: Thành viên nhóm -->
            <div class="footer-column">
                <h3>👥 Thành viên nhóm</h3>
                <ul class="team-list">
                    <li>
                        <span class="label">Nhóm trưởng:</span>
                        <span class="team-leader">Nguyễn Lê Anh Khoa</span>
                    </li>
                    <li>
                        <span class="label">Thành viên:</span>
                        <span>Đoàn Phùng Hải Lân</span>
                    </li>
                    <li>Lê Nhật Nam</li>
                    <li>Nguyễn Hữu Phúc</li>
                    <li>Lê Trần Việt Tiến</li>
                </ul>
            </div>

            <!-- CỘT 3: Liên hệ -->
            <div class="footer-column">
                <h3>📞 Liên hệ</h3>
                <ul class="contact-list">
                    <li>
                        <span class="contact-icon">✉️</span>
                        <a href="mailto:student232330@ptnk.edu.vn">student232330@ptnk.edu.vn</a>
                    </li>
                    <li>
                        <span class="contact-icon">📱</span>
                        <a href="tel:+84843927xxx">0843927xxx</a>
                    </li>
                    <li>
                        <span class="contact-icon">📍</span>
                        <span>TP Hồ Chí Minh, Việt Nam</span>
                    </li>
                </ul>

                <!-- Social Links -->
                <div class="social-links">
                    <a href="#" title="Facebook">📘</a>
                    <a href="#" title="YouTube">▶️</a>
                    <a href="#" title="Instagram">📷</a>
                    <a href="#" title="TikTok">🎵</a>
                </div>
            </div>
        </div>

        <!-- COPYRIGHT -->
        <div class="footer-bottom">
            <p>© 2025 IELTS Reading Pro - Dự án Tin học 12 - Trường THPT Võ Trường Toản</p>
            <p>Made with <span class="heart">❤️</span> for IELTS learners</p>
        </div>
    </footer>

    <script>
        // LẤY KẾT QUẢ
        const result = JSON.parse(localStorage.getItem('testResult'));

        if (!result) {
            alert('Không tìm thấy kết quả test!');
            window.location.href = 'dashboard.html';
        }

        // HIỂN THỊ THÔNG TIN
        const score = result.score;
        const total = result.total;
        const correct = result.correct;
        const percentage = Math.round((correct / total) * 100);
        const timeUsed = result.timeUsed;

        document.getElementById('testName').textContent = result.testTitle;
        document.getElementById('score').textContent = `${score}/${total}`;
        document.getElementById('accuracy').textContent = `${percentage}%`;

        const minutes = Math.floor(timeUsed / 60);
        const seconds = timeUsed % 60;
        document.getElementById('timeUsed').textContent = `${minutes}:${seconds.toString().padStart(2, '0')}`;

        // FEEDBACK
        const feedbackEl = document.getElementById('feedback');
        const trophyEl = document.getElementById('trophy');
        const titleEl = document.getElementById('resultTitle');

        if (percentage >= 90) {
            trophyEl.textContent = '🏆';
            titleEl.textContent = 'Xuất sắc!';
            feedbackEl.innerHTML = `
                <h3>🌟 Tuyệt vời!</h3>
                <p>Bạn đã đạt ${percentage}% - Trình độ IELTS Reading của bạn rất tốt! Tiếp tục phát huy nhé!</p>
            `;
        } else if (percentage >= 75) {
            trophyEl.textContent = '🥇';
            titleEl.textContent = 'Rất tốt!';
            feedbackEl.innerHTML = `
                <h3>👏 Làm tốt lắm!</h3>
                <p>Bạn đạt ${percentage}% - Kết quả khá ấn tượng! Tiếp tục luyện tập để đạt điểm cao hơn!</p>
            `;
        } else if (percentage >= 60) {
            trophyEl.textContent = '🥈';
            titleEl.textContent = 'Khá tốt!';
            feedbackEl.innerHTML = `
                <h3>💪 Tiến bộ rõ rệt!</h3>
                <p>Bạn đạt ${percentage}% - Đang đi đúng hướng! Xem lại các câu sai để cải thiện thêm nhé!</p>
            `;
        } else if (percentage >= 50) {
            trophyEl.textContent = '🥉';
            titleEl.textContent = 'Cố gắng lên!';
            feedbackEl.innerHTML = `
                <h3>📚 Cần cải thiện!</h3>
                <p>Bạn đạt ${percentage}% - Hãy xem kỹ phần giải thích và làm lại để hiểu rõ hơn nhé!</p>
            `;
        } else {
            trophyEl.textContent = '💪';
            titleEl.textContent = 'Đừng bỏ cuộc!';
            feedbackEl.innerHTML = `
                <h3>🎯 Hãy thử lại!</h3>
                <p>Bạn đạt ${percentage}% - Đọc kỹ passage và luyện tập nhiều hơn sẽ giúp bạn tiến bộ nhanh!</p>
            `;
        }

        // PROGRESS BARS
        document.getElementById('correctCount').textContent = `${correct}/${total}`;
        document.getElementById('incorrectCount').textContent = `${total - correct}/${total}`;

        setTimeout(() => {
            document.getElementById('correctBar').style.width = percentage + '%';
            document.getElementById('incorrectBar').style.width = (100 - percentage) + '%';
        }, 300);

        // CHI TIẾT TỪNG CÂU
        const answersContainer = document.getElementById('answersContainer');
        const questions = result.questions;
        const userAnswers = result.answers;

        questions.forEach(q => {
            const userAnswer = userAnswers[q.id];
            const isCorrect = userAnswer === q.correct;

            const answerDiv = document.createElement('div');
            answerDiv.className = `answer-item ${isCorrect ? 'correct' : 'incorrect'}`;

            const options = ['A', 'B', 'C', 'D'];

            answerDiv.innerHTML = `
                <div class="question-number">
                    ${isCorrect ? '✅' : '❌'} Câu ${q.id}
                </div>
                <div class="question-text">${q.text}</div>
                <div class="answer-details">
                    ${isCorrect ? `
                        <div>
                            <span>✓</span>
                            <span>Bạn đã chọn đúng:</span>
                            <span class="correct-user-answer">${options[userAnswer]}. ${q.options[userAnswer]}</span>
                        </div>
                    ` : `
                        <div>
                            <span>✗</span>
                            <span>Bạn đã chọn:</span>
                            <span class="your-answer">${userAnswer !== undefined ? options[userAnswer] + '. ' + q.options[userAnswer] : 'Chưa trả lời'}</span>
                        </div>
                        <div>
                            <span>✓</span>
                            <span>Đáp án đúng:</span>
                            <span class="correct-answer">${options[q.correct]}. ${q.options[q.correct]}</span>
                        </div>
                    `}
                </div>
            `;

            answersContainer.appendChild(answerDiv);
        });

        // LÀM LẠI TEST
        function retakeTest() {
            if (confirm('Bạn có muốn làm lại bài test này không?')) {
                localStorage.removeItem('testResult');
                window.location.href = 'test.html';
            }
        }
    </script>
</body>
</html>'''

# %%
# -*- coding: utf-8 -*-
"""
IELTS Reading Practice - CELL 7
Tạo file test-data.js với FULL 5 BÀI TEST
"""

import os

# Đảm bảo đang ở đúng thư mục
os.chdir('/content/ielts_reading_pro')

# ==================== FILE test-data.js ====================
test_data_js = '''// IELTS READING TEST DATA - ALL 5 TESTS
// Mỗi test: 1 passage, 8 câu hỏi

const TEST_DATA = {
    1: {
        title: "Test 1: Climate Change",
        passage: {
            title: "The Impact of Climate Change",
            text: `
                <p><strong>The Impact of Climate Change</strong></p>

                <p>Climate change has become one of the most pressing issues facing humanity in the 21st century. Rising global temperatures, melting ice caps, and increasingly severe weather events are just some of the visible signs that our planet's climate is undergoing significant transformation. Scientists overwhelmingly agree that human activities, particularly the burning of fossil fuels and deforestation, are the primary drivers of these changes.</p>

                <p>The consequences of climate change are far-reaching and affect virtually every aspect of life on Earth. Rising sea levels threaten coastal communities, with some island nations facing the possibility of complete submersion. Agricultural patterns are shifting as traditional growing seasons become unpredictable, potentially leading to food security issues in many regions. Extreme weather events such as hurricanes, droughts, and floods are becoming more frequent and intense, causing both human suffering and economic damage.</p>

                <p>The impact on biodiversity is equally concerning. Many species are struggling to adapt to rapidly changing environmental conditions. Coral reefs, often called the rainforests of the sea, are experiencing widespread bleaching due to warming ocean temperatures. Polar bears in the Arctic are losing their hunting grounds as sea ice melts earlier each year. These changes ripple through entire ecosystems, affecting food chains and ecological balance.</p>

                <p>However, the situation is not entirely hopeless. Many countries and organizations are taking action to mitigate climate change and adapt to its effects. Renewable energy sources such as solar and wind power are becoming more affordable and widespread. International agreements like the Paris Climate Accord aim to limit global temperature increases. Individuals are also making lifestyle changes, from reducing meat consumption to using public transportation.</p>

                <p>The challenge ahead requires unprecedented global cooperation and sustained effort. While the task is daunting, many experts believe that with sufficient political will and technological innovation, humanity can still avoid the most catastrophic effects of climate change and create a more sustainable future for generations to come.</p>
            `
        },
        questions: [
            {
                id: 1,
                text: "1. What is identified as the primary cause of climate change?",
                options: [
                    "Natural weather cycles",
                    "Human activities like burning fossil fuels",
                    "Volcanic eruptions",
                    "Solar radiation changes"
                ],
                correct: 1
            },
            {
                id: 2,
                text: "2. According to the passage, rising sea levels particularly threaten:",
                options: [
                    "Mountain communities",
                    "Desert regions",
                    "Coastal communities and island nations",
                    "Forest areas"
                ],
                correct: 2
            },
            {
                id: 3,
                text: "3. How does climate change affect agriculture?",
                options: [
                    "It increases crop yields everywhere",
                    "It makes growing seasons unpredictable",
                    "It has no effect on farming",
                    "It only affects tropical regions"
                ],
                correct: 1
            },
            {
                id: 4,
                text: "4. What is happening to coral reefs due to climate change?",
                options: [
                    "They are growing faster",
                    "They are moving to deeper waters",
                    "They are experiencing widespread bleaching",
                    "They are unaffected"
                ],
                correct: 2
            },
            {
                id: 5,
                text: "5. The passage mentions that polar bears are affected by:",
                options: [
                    "Increased hunting by humans",
                    "Loss of hunting grounds due to melting sea ice",
                    "Overpopulation",
                    "Disease outbreaks"
                ],
                correct: 1
            },
            {
                id: 6,
                text: "6. Which renewable energy sources are mentioned as becoming more widespread?",
                options: [
                    "Nuclear and hydroelectric",
                    "Solar and wind power",
                    "Geothermal and tidal",
                    "Biomass and hydrogen"
                ],
                correct: 1
            },
            {
                id: 7,
                text: "7. What is the purpose of the Paris Climate Accord?",
                options: [
                    "To increase global trade",
                    "To limit global temperature increases",
                    "To promote fossil fuel use",
                    "To build new cities"
                ],
                correct: 1
            },
            {
                id: 8,
                text: "8. The author's overall tone about solving climate change is:",
                options: [
                    "Completely pessimistic",
                    "Overly optimistic",
                    "Cautiously hopeful",
                    "Indifferent"
                ],
                correct: 2
            }
        ]
    },

    2: {
        title: "Test 2: Artificial Intelligence",
        passage: {
            title: "The Rise of Artificial Intelligence",
            text: `
                <p><strong>The Rise of Artificial Intelligence</strong></p>

                <p>Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century. From virtual assistants like Siri and Alexa to self-driving cars and advanced medical diagnosis systems, AI is reshaping how we live, work, and interact with the world around us.</p>

                <p>At its core, AI refers to computer systems designed to perform tasks that typically require human intelligence. These tasks include visual perception, speech recognition, decision-making, and language translation. Machine learning, a subset of AI, enables computers to learn from data without being explicitly programmed for every scenario.</p>

                <p>The potential benefits of AI are enormous. In healthcare, AI algorithms can analyze medical images with accuracy rivaling or exceeding human doctors, potentially saving countless lives through early disease detection. In education, AI-powered adaptive learning systems can personalize instruction to each student's needs. In business, AI can automate repetitive tasks, allowing humans to focus on creative and strategic work.</p>

                <p>However, the rapid advancement of AI also raises important concerns. Job displacement is a major worry, as automation could make many current jobs obsolete. There are also ethical questions about AI decision-making, privacy concerns related to data collection, and fears about AI systems operating beyond human control. Experts emphasize the need for responsible AI development with proper safeguards and regulations.</p>

                <p>Looking ahead, the future of AI holds both promise and uncertainty. As the technology continues to evolve, society must balance innovation with caution, ensuring that AI serves humanity's best interests while minimizing potential risks.</p>
            `
        },
        questions: [
            {
                id: 1,
                text: "1. What is the main topic of the passage?",
                options: [
                    "The history of computers",
                    "The impact of Artificial Intelligence",
                    "Virtual assistants technology",
                    "Self-driving cars development"
                ],
                correct: 1
            },
            {
                id: 2,
                text: "2. According to the passage, machine learning allows computers to:",
                options: [
                    "Be programmed for every scenario",
                    "Replace human workers completely",
                    "Learn from data without explicit programming",
                    "Only perform simple tasks"
                ],
                correct: 2
            },
            {
                id: 3,
                text: "3. In healthcare, AI can:",
                options: [
                    "Replace all doctors",
                    "Analyze medical images accurately",
                    "Only assist with simple diagnoses",
                    "Make treatment decisions alone"
                ],
                correct: 1
            },
            {
                id: 4,
                text: "4. Which benefit of AI in education is mentioned?",
                options: [
                    "Replacing teachers",
                    "Reducing class sizes",
                    "Personalizing instruction to students",
                    "Eliminating homework"
                ],
                correct: 2
            },
            {
                id: 5,
                text: "5. What is a major concern about AI mentioned in the passage?",
                options: [
                    "It's too expensive",
                    "Job displacement",
                    "It's too slow",
                    "It's difficult to use"
                ],
                correct: 1
            },
            {
                id: 6,
                text: "6. The passage suggests that AI development should include:",
                options: [
                    "No regulations",
                    "Complete freedom",
                    "Proper safeguards and regulations",
                    "Limited research"
                ],
                correct: 2
            },
            {
                id: 7,
                text: "7. What does the author say about the future of AI?",
                options: [
                    "It's completely certain",
                    "It holds both promise and uncertainty",
                    "It will solve all problems",
                    "It should be stopped"
                ],
                correct: 1
            },
            {
                id: 8,
                text: "8. The author's overall tone toward AI can best be described as:",
                options: [
                    "Completely negative",
                    "Overly optimistic",
                    "Balanced and cautious",
                    "Indifferent"
                ],
                correct: 2
            }
        ]
    },

    3: {
        title: "Test 3: Ancient Rome",
        passage: {
            title: "The Legacy of Ancient Rome",
            text: `
                <p><strong>The Legacy of Ancient Rome</strong></p>

                <p>Ancient Rome, one of history's most influential civilizations, continues to shape modern society in countless ways. From its legendary founding in 753 BCE to the fall of the Western Roman Empire in 476 CE, Rome's impact on law, government, architecture, language, and culture has been profound and enduring.</p>

                <p>Perhaps Rome's greatest contribution was in the realm of law and governance. The Roman legal system, particularly the concept of "innocent until proven guilty" and the right to a fair trial, forms the foundation of many modern legal systems. The Roman Republic's system of checks and balances influenced the framers of the United States Constitution. Latin terms like "habeas corpus" and "pro bono" remain part of legal vocabulary today.</p>

                <p>Roman engineering and architecture also left an indelible mark on the world. The Romans were master builders who constructed roads, aqueducts, and buildings that have lasted for millennia. The famous saying "All roads lead to Rome" reflects the extensive network of roads that facilitated trade and military movements across the empire. Roman architectural innovations, such as the arch, dome, and concrete, are still used in modern construction. Iconic structures like the Colosseum and Pantheon continue to inspire architects worldwide.</p>

                <p>The Latin language, spoken throughout the Roman Empire, became the foundation for the Romance languages including Italian, French, Spanish, Portuguese, and Romanian. Even English, though a Germanic language, contains numerous Latin-derived words, particularly in academic, legal, and scientific terminology. Many common phrases like "et cetera," "versus," and "alumni" are direct borrowings from Latin.</p>

                <p>Understanding Ancient Rome helps us comprehend the roots of Western civilization. From democratic principles to urban planning, from literature to military strategy, Roman innovations and ideas continue to influence how we organize societies, build cities, and think about citizenship and civic duty in the modern world.</p>
            `
        },
        questions: [
            {
                id: 1,
                text: "1. When was Ancient Rome legendarily founded?",
                options: ["476 CE", "753 BCE", "100 BCE", "500 CE"],
                correct: 1
            },
            {
                id: 2,
                text: "2. Which legal concept is attributed to Roman law?",
                options: ["Trial by jury", "Innocent until proven guilty", "Death penalty", "Common law"],
                correct: 1
            },
            {
                id: 3,
                text: "3. The Roman Republic's system influenced which modern constitution?",
                options: ["The British Constitution", "The French Constitution", "The United States Constitution", "The German Constitution"],
                correct: 2
            },
            {
                id: 4,
                text: "4. What architectural innovations are mentioned as Roman contributions?",
                options: ["Steel frames and glass", "Arch, dome, and concrete", "Skyscrapers and elevators", "Suspension bridges"],
                correct: 1
            },
            {
                id: 5,
                text: "5. Which famous Roman structure is mentioned as inspiring modern architects?",
                options: ["The Forum", "Hadrian's Wall", "The Colosseum", "The Circus Maximus"],
                correct: 2
            },
            {
                id: 6,
                text: "6. Latin is described as the foundation for which language family?",
                options: ["Germanic languages", "Slavic languages", "Romance languages", "Celtic languages"],
                correct: 2
            },
            {
                id: 7,
                text: "7. English contains many Latin-derived words particularly in:",
                options: ["Casual conversation", "Academic, legal, and scientific terminology", "Slang expressions", "Sports commentary"],
                correct: 1
            },
            {
                id: 8,
                text: "8. According to the passage, understanding Ancient Rome helps us:",
                options: ["Learn ancient languages", "Build better roads", "Comprehend the roots of Western civilization", "Travel through Europe"],
                correct: 2
            }
        ]
    },

    4: {
        title: "Test 4: Modern Medicine",
        passage: {
            title: "Advances in Modern Medicine",
            text: `
                <p><strong>Advances in Modern Medicine</strong></p>

                <p>The 21st century has witnessed remarkable advances in medical science that would have seemed like science fiction just a few decades ago. From personalized medicine based on genetic profiles to minimally invasive surgical techniques, modern medicine is transforming how we prevent, diagnose, and treat diseases.</p>

                <p>One of the most significant developments has been in the field of genomics. The completion of the Human Genome Project in 2003 opened up new possibilities for understanding how genes influence health and disease. Today, genetic testing can identify predispositions to certain conditions, allowing for early intervention and personalized treatment plans. Gene therapy, once purely theoretical, is now being used to treat previously incurable genetic disorders by correcting defective genes.</p>

                <p>Medical imaging technology has also advanced dramatically. Modern MRI and CT scanners can produce incredibly detailed three-dimensional images of the human body, enabling doctors to detect problems earlier and with greater accuracy. PET scans can track metabolic activity, helping identify cancer cells and monitor treatment effectiveness. These non-invasive diagnostic tools have reduced the need for exploratory surgery and improved patient outcomes.</p>

                <p>Surgical techniques have become increasingly sophisticated and less invasive. Robotic surgery allows for greater precision and smaller incisions, resulting in faster recovery times and fewer complications. Laparoscopic procedures, which use small cameras and instruments inserted through tiny incisions, have become routine for operations that once required large, open incisions. These minimally invasive approaches reduce pain, scarring, and hospital stays.</p>

                <p>Looking forward, emerging technologies like artificial intelligence, nanotechnology, and 3D bioprinting promise to revolutionize medicine even further. AI algorithms can now analyze medical data faster and more accurately than humans in some cases. Researchers are developing microscopic robots that could one day travel through the bloodstream to deliver drugs directly to diseased cells. While challenges remain, the future of medicine appears brighter than ever before.</p>
            `
        },
        questions: [
            {
                id: 1,
                text: "1. What major project was completed in 2003?",
                options: ["The Mars Rover Mission", "The Human Genome Project", "The International Space Station", "The Internet Protocol"],
                correct: 1
            },
            {
                id: 2,
                text: "2. Gene therapy is now being used to:",
                options: ["Enhance athletic performance", "Correct defective genes", "Change eye color", "Increase intelligence"],
                correct: 1
            },
            {
                id: 3,
                text: "3. What can PET scans track in the body?",
                options: ["Blood pressure", "Bone density", "Metabolic activity", "Heart rate"],
                correct: 2
            },
            {
                id: 4,
                text: "4. Modern imaging technology has reduced the need for:",
                options: ["Medication", "Exploratory surgery", "Physical therapy", "Hospital visits"],
                correct: 1
            },
            {
                id: 5,
                text: "5. What advantage does robotic surgery offer?",
                options: ["Lower costs", "Greater precision and smaller incisions", "Faster operations", "No anesthesia needed"],
                correct: 1
            },
            {
                id: 6,
                text: "6. Laparoscopic procedures use:",
                options: ["Large open incisions", "Radiation therapy", "Small cameras and instruments through tiny incisions", "Ultrasound waves"],
                correct: 2
            },
            {
                id: 7,
                text: "7. According to the passage, AI algorithms in medicine can:",
                options: ["Replace all doctors", "Perform surgery independently", "Analyze medical data faster and more accurately", "Cure all diseases"],
                correct: 2
            },
            {
                id: 8,
                text: "8. What are researchers developing with nanotechnology?",
                options: ["Larger surgical tools", "Microscopic robots for drug delivery", "New antibiotics", "Stronger vaccines"],
                correct: 1
            }
        ]
    },

    5: {
        title: "Test 5: Space Exploration",
        passage: {
            title: "The Future of Space Exploration",
            text: `
                <p><strong>The Future of Space Exploration</strong></p>

                <p>Space exploration stands at an exciting crossroads as we enter a new era of cosmic discovery. After decades of government-led missions, private companies are now joining the quest to explore the solar system and beyond. This collaboration between public and private sectors is accelerating progress and opening up possibilities that were once confined to science fiction.</p>

                <p>Mars has emerged as the primary target for human exploration in the coming decades. Multiple space agencies and private companies are working on technologies to establish a permanent human presence on the Red Planet. The challenges are immense: the journey takes approximately seven months, the Martian atmosphere is unbreathable, and the surface is bombarded by harmful radiation. However, recent discoveries of water ice beneath the surface and the successful operation of rovers like Perseverance demonstrate that a Mars mission is achievable.</p>

                <p>The search for extraterrestrial life remains one of the most compelling reasons for space exploration. Scientists focus particularly on Mars, Europa (one of Jupiter's moons), and Enceladus (a moon of Saturn), all of which show evidence of liquid water—a key ingredient for life as we know it. Advanced telescopes are also examining exoplanets in distant solar systems, looking for atmospheric signatures that might indicate biological activity.</p>

                <p>Commercial spaceflight is becoming increasingly viable, with companies like SpaceX and Blue Origin successfully launching reusable rockets. This reusability dramatically reduces the cost of reaching orbit, making space more accessible for research, tourism, and eventual colonization. Space tourism, once purely science fiction, has become reality, with several private citizens already having traveled to the International Space Station.</p>

                <p>Looking beyond our solar system, new propulsion technologies are being researched that could enable interstellar travel. While journeys to even the nearest stars would take decades with current technology, concepts like solar sails, nuclear propulsion, and even theoretical antimatter engines offer hope for future generations to reach other star systems. The dream of becoming a multi-planetary species is slowly but surely becoming more tangible.</p>
            `
        },
        questions: [
            {
                id: 1,
                text: "1. What has changed in recent space exploration?",
                options: ["Only governments are involved", "Private companies are joining government efforts", "Exploration has stopped", "Focus has shifted to ocean exploration"],
                correct: 1
            },
            {
                id: 2,
                text: "2. How long does the journey to Mars take?",
                options: ["One month", "Three months", "Approximately seven months", "One year"],
                correct: 2
            },
            {
                id: 3,
                text: "3. What recent discovery makes a Mars mission more achievable?",
                options: ["Gold deposits", "Alien artifacts", "Water ice beneath the surface", "Breathable atmosphere"],
                correct: 2
            },
            {
                id: 4,
                text: "4. Which celestial bodies are mentioned as targets in the search for life?",
                options: ["Venus and Mercury", "Mars, Europa, and Enceladus", "Neptune and Pluto", "The Moon and Titan"],
                correct: 1
            },
            {
                id: 5,
                text: "5. What makes water significant in the search for life?",
                options: ["It's valuable for mining", "It's a key ingredient for life as we know it", "It can be used as rocket fuel", "It indicates volcanic activity"],
                correct: 1
            },
            {
                id: 6,
                text: "6. How do reusable rockets benefit space exploration?",
                options: ["They travel faster", "They dramatically reduce the cost of reaching orbit", "They can carry more passengers", "They don't need fuel"],
                correct: 1
            },
            {
                id: 7,
                text: "7. What has become reality that was once science fiction?",
                options: ["Teleportation", "Time travel", "Space tourism", "Artificial gravity"],
                correct: 2
            },
            {
                id: 8,
                text: "8. What propulsion technologies are mentioned for potential interstellar travel?",
                options: ["Chemical rockets only", "Solar sails, nuclear propulsion, and antimatter engines", "Wind power", "Steam engines"],
                correct: 1
            }
        ]
    }
};

// Export cho test.html sử dụng
if (typeof module !== 'undefined' && module.exports) {
    module.exports = TEST_DATA;
}
'''

# %%
import os
os.chdir('/content/ielts_reading_pro')

# Kiểm tra file tồn tại
if os.path.exists('test-data.js'):
    print("✅ File test-data.js ĐÃ TỒN TẠI!")
    print(f"📏 Kích thước: {os.path.getsize('test-data.js')} bytes")
else:
    print("❌ File test-data.js CHƯA TỒN TẠI!")
    print("👉 Hãy chạy Cell 7 trước!")

# List tất cả files
print("\n📂 Danh sách files trong thư mục:")
for f in os.listdir('.'):
    if f.endswith('.html') or f.endswith('.js'):
        print(f"   ✓ {f}")

# %%
# -*- coding: utf-8 -*-
"""
IELTS READING - CHẠY LOCALHOST SERVER (FIXED)
Chạy website với ngrok - ĐÃ FIX LỖI AUTHTOKEN
"""

import os
import subprocess
import time
from threading import Thread

print("=" * 70)
print("🚀 KHỞI ĐỘNG LOCAL SERVER")
print("=" * 70)

# Kiểm tra folder tồn tại
if not os.path.exists('/content/ielts_reading_pro'):
    print("❌ Chưa có folder 'ielts_reading_pro'!")
    print("💡 Hãy chạy các cell tạo files trước!")
    exit()

os.chdir('/content/ielts_reading_pro')

# Cài đặt pyngrok
print("\n📦 Đang cài đặt pyngrok...")
subprocess.run(['pip', 'install', 'pyngrok', '-q'], check=True)

from pyngrok import ngrok, conf

# ===== QUAN TRỌNG: NHẬP AUTHTOKEN Ở ĐÂY =====
NGROK_AUTHTOKEN = "35vXR0rrAyItyfymXYtaPpS5DYd_87tzKazAqKZkDTzGMZWwP"  # <-- Thay token vào đây!

if NGROK_AUTHTOKEN == "35vXR0rrAyItyfymXYtaPpS5DYd_87tzKazAqKZkDTzGMZWwP":
    print("\n" + "=" * 70)
    print("⚠️  BẠN CHƯA NHẬP AUTHTOKEN!")
    print("=" * 70)
    print("\n📝 Làm theo các bước sau:")
    print("   1. Truy cập: https://dashboard.ngrok.com/signup")
    print("   2. Đăng ký miễn phí (dùng Google/GitHub)")
    print("   3. Vào: https://dashboard.ngrok.com/get-started/your-authtoken")
    print("   4. Copy token và paste vào dòng 31 của cell này")
    print("   5. Chạy lại cell này!")
    print("\n" + "=" * 70)
    exit()

# Set authtoken
print("\n🔑 Đang xác thực ngrok...")
ngrok.set_auth_token(NGROK_AUTHTOKEN)

# Khởi động HTTP server trong background
def start_server():
    os.system('python -m http.server 8000 > /dev/null 2>&1')

print("🔧 Đang khởi động HTTP server trên port 8000...")
server_thread = Thread(target=start_server, daemon=True)
server_thread.start()

# Đợi server khởi động
time.sleep(3)

# Tạo ngrok tunnel
print("🌐 Đang tạo public URL với ngrok...")
try:
    # Dừng tất cả tunnels cũ
    ngrok.kill()

    # Tạo tunnel mới
    public_url = ngrok.connect(8000, bind_tls=True)

    print("\n" + "=" * 70)
    print("✅ THÀNH CÔNG! SERVER ĐÃ CHẠY!")
    print("=" * 70)
    print(f"\n🌐 LINK WEBSITE CỦA BẠN:")
    print(f"\n   {public_url}")
    print(f"\n📱 Thông tin:")
    print(f"   - Link hoạt động trong 2 giờ")
    print(f"   - Bất kỳ ai có link đều có thể truy cập")
    print(f"   - Account demo: demo@test.com / 123456")
    print(f"\n💡 Lưu ý:")
    print(f"   - Mở link trong tab mới")
    print(f"   - Nếu lỗi, chờ 5 giây reload lại")
    print(f"   - Giữ cell này đang chạy (không stop!)")
    print("\n" + "=" * 70)

    # Giữ server chạy
    print("\n⏳ Server đang chạy... (Nhấn ■ Stop để tắt)\n")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        print("\n🛑 Đã dừng server!")
        ngrok.kill()

except Exception as e:
    print(f"\n❌ Lỗi: {e}")
    print("\n🔍 Nguyên nhân có thể:")
    print("   - Token sai/hết hạn")
    print("   - Mạng chậm")
    print("   - Port 8000 đang bận")
    print("\n💡 Giải pháp:")
    print("   1. Kiểm tra lại token")
    print("   2. Restart Runtime")
    print("   3. Chạy lại từ đầu")
